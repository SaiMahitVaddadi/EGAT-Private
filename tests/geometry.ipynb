# %%
import sys
sys.path.append("/Users/svaddadi/Documents/GitHub/")
import EGAT
from EGAT import src
from EGAT.src.utils.descriptors.egat.molmatdesc import MolMatDesc
from EGAT.src.utils.descriptors.geometry.geometry import ConformerGenerator
from rdkit import Chem

# %%
smi = 'CCO'
descriptor = MolMatDesc(smi)
descriptor.run()
# Out:
# [18:58:36]
#
# ****
# Pre-condition Violation
# getNumImplicitHs() called without preceding call to calcImplicitValence()
# Violation occurred on line 304 in file /Users/runner/work/rdkit-pypi/rdkit-pypi/build/temp.macosx-11.0-arm64-cpython-310/rdkit/Code/GraphMol/Atom.cpp
# Failed Expression: d_implicitValence > -1
# ****
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 2
#       1 smi = 'CCO'
# ----> 2 descriptor = MolMatDesc(smi)
#       3 descriptor.run()
#
# File ~/Documents/GitHub/EGAT/src/utils/descriptors/egat/molmatdesc.py:105, in MolMatDesc.__init__(self, AM_smiles)
#      98 """
#      99 Initialize the MolMatDesc object with a SMILES string.
#     100
#     101 Parameters:
#     102 AM_smiles (str): Atom-mapped SMILES string of the molecule.
#     103 """
#     104 self.mol = Chem.MolFromSmiles(AM_smiles, sanitize=False)
# --> 105 self.AddHydrogens()
#     106 self.AddMapping()
#     107 self.sorted_atoms = sorted(self.mol.GetAtoms(), key=lambda atom: atom.GetAtomMapNum())
#
# File ~/Documents/GitHub/EGAT/src/utils/descriptors/egat/molmatdesc.py:115, in MolMatDesc.AddHydrogens(self)
#     111 def AddHydrogens(self):
#     112     """
#     113     Add hydrogens to the molecule.
#     114     """
# --> 115     self.mol = Chem.AddHs(self.mol)
#
# RuntimeError: Pre-condition Violation
# 	getNumImplicitHs() called without preceding call to calcImplicitValence()
# 	Violation occurred on line 304 in file Code/GraphMol/Atom.cpp
# 	Failed Expression: d_implicitValence > -1
# 	RDKIT: 2024.09.5
# 	BOOST: 1_85

# %%
descriptor.new_mol

# %%
descriptor.new_smiles
# Out:
# 'CCO'

# %%
import yarp as yp

cule = yp.yarpecule('CCO')

# %%
dir(cule)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'adj_mat',
#  'atom_hashes',
#  'atom_neighbors',
#  'bo_dict',
#  'bond_mat_scores',
#  'bond_mats',
#  'canonicalize',
#  'draw_bmats',
#  'elements',
#  'fc',
#  'find_basic_attributes',
#  'find_lewis',
#  'find_rings',
#  'geo',
#  'hash',
#  'join',
#  'mapping',
#  'masses',
#  'n_e_accept',
#  'n_e_donate',
#  'q',
#  'rings',
#  'update_masses']

# %%
cule.elements
# Out:
# ['c', 'c', 'o', 'h', 'h', 'h', 'h', 'h', 'h']
