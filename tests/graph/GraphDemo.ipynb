# %%
import sys
sys.path.append("/Users/svaddadi/Documents/GitHub/")
import EGAT
from EGAT import src
from EGAT.src.graph.molecular.Molecule import MoleculeFeaturizer
from EGAT.src.graph.molecular.MoleculeGeometry import MoleculeFeaturizerwithGeometry
from EGAT.src.graph.molecular.MoleculeGlobal import MoleculeFeaturizerwithPadding
from EGAT.src.params.graph import GraphParams
from EGAT.src.graph.base.base import BaseReactionParams,BaseFeaturizer
from EGAT.src.graph.base.reaction import BaseReactionFeaturizer
from EGAT.src.graph.base.component import BaseReactionComponentFeaturizer
from rich import inspect
from rich.console import Console


def get_dir_to_txt_file(object,filename):
    """
    Get the directory of the txt file
    """
    # Create a Console that writes to a file
    with open(filename, "w") as file:
        console = Console(file=file)
        inspect(object, console=console)
# Out:
# WARNING: Ignoring invalid distribution -dkit (/opt/anaconda3/envs/EGAT_CPU/lib/python3.10/site-packages)

# %%
params = BaseReactionParams()
params.acidbase = 'BL'
params.getradical = 'RDKit'
params.stereo_full = True
smiles = "CC(=O)C1=CC=C(C=C1)C(=O)O"
basegraph = BaseFeaturizer(smiles,params)
basereactiongraph= BaseReactionComponentFeaturizer(smiles,params)

# %%
params = GraphParams()
# This is the way to set the parameters if you want explicit Acid-Base Information
params.acidbase = 'Lewis'
params.getacidbaseinfo = True
# This is the way to get radicals
# Note: For YARP,  YARP can give multiple smiles based on the resonance structure. The way we handle this is by obtaining x different graphs for the same y.
# With that, we would need to change the dataloader to handle such cases as it also happens with the conformational sampling. 
params.getradical = 'RDKit'
# This is the way to get spiro and brdgehead information. 
params.getspiro = True
params.getbridgehead = True
# This is the way to get fused ring information.
params.getfusedinformation = True
# This is the way to get rotatable bond information.
params.getrotatablebonds = True
# This is the way to get gasteiger charges.
params.charge = 'Gasteiger'
# This is the way to get BRICS Decomposition locations. 
params.getbrics = True
params.checkbricsbond = True 
# This is the way to get Electronegativity locations. 
params.getelectronegativity = True
# This is the way to get the bond dipoles.
params.getdipole = True
# This is the way to get the sigma and pi electrons.
params.getpielectrons = True
params.getsigmaelectrons = True
# This is the way to get the intrinsic state.
params.getintrinsicstate = True
# This is the way to get the eta and beta values.
params.getetabeta = True
# This is the way to get the ionization potential.
params.getionizationpotential = True
params.getionizationpotentialpooled = True
# This get core electrons
params.getcoreelectrons = True
# this gets the ramification number. 
params.getramificationnumber = True
params.getjazzydelta=  True
params.getjazzyfe = True
params.getlocantcount=True
params.getpolarity = True
params.threshold = 10.0
params.covalentnumber = "exp"
params.ps_size = (1.0, 1.5)
params.kallisto_thresholdCN = 10.0
params.kallisto_thresholdBond = 0.5
params.vdw_scale = 1.0
params.vdwtype = "truhlar"
params.getCN = True
params.getPS = True
params.getAPC = True
params.getvdwkallisto = True
params.getAP = True
params.useabc = 'reg'
params.useabs = 'gg'
params.getbarysz = True
params.getats = 'ATS'
params.getdetour = True
params.getburdenmat = 'reg'
params.burdenweight = 'reg'
params.getpropsrelativetocarbon = False #Needs Work
params.getvertexdistancedegree = True
params.getbalabanbondfactor = True
params.getsuperdentic = True
params.geteccentricity = True
params.getschultz = True
params.getgutman = True
params.getxui = True
params.gethorary = True
params.getmohar = 'laplacian'
params.gethp = True
params.getcorecount = True
params.getvem = True
params.getetacomposite = True
params.getetapsi = True
params.getgravity = True
params.getzagreb = 2
params.getharmonic = True
params.getsombor = True
params.getrandic = True
params.getnirmala = True
params.getsoss = True
params.getaugmentedgraphattributes = True
params.gethyperbolic = True
params.getaugzagreb = True
params.getklein = True
params.gethyperwiener = True
params.getwiener = True
params.gethdsa = True
params.getets = True
params.getinformationcontent = 0
params.getweightedinformationcontent = 0
params.getmoleculardistanceedge = True
params.gettopocharge = 3
params.getSMR = ['Li', 'logPregion','Ri']
params.getMoRSE = 'cos'
params.getchi = 3
params.getedgewiener = True
params.getvertexadjacency = True
params.getTPSA = True
params.getASA = True
params.LogS = True
params.getEstate = 'all'
params.getchivalence = 3
params.MDEvalences = [1, 1]
params.MDEreference = 'C'
params.mohar = 'unnormalized'
params.getvewi = True
params.getvewibyorder = 3
params.getedgewienerbyorder = 3
params.IC_weight = 'mass'
params.getresonance = True
graph = MoleculeFeaturizer('CCCCC',params)
graph.run()
# Out:
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 1138.77it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 1127.25it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 929.78it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 1471.27it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 1405.17it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 1469.84it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 4283.40it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2196.28it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2318.72it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 3915.62it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2925.69it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2309.93it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2183.61it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 3193.89it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2992.33it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2000.73it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 1268.85it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 38997.49it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 10592.82it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 5346.40it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 8905.10it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 9779.36it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 13930.63it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 7600.43it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 13069.83it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 9599.82it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 10602.50it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 13541.17it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 37656.60it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 37328.59it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 19400.87it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 18366.93it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 10343.27it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 44249.67it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 8829.72it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 9976.84it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 24017.09it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 7870.18it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 24479.36it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 41154.97it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 44002.74it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 32844.43it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 9270.27it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 19383.71it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 46123.61it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 28837.37it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 34200.61it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 30300.08it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 30014.05it/s]

# %%
params.conformer.generator = 'RDKit'
params.conformer.nconfs = 1
params.getsterimol = True
params.local_cutoff = 4.0
params.use_vdw = True
params.removecoordinationinfo = True
params.getdistancetocenterofmass = True
params.getsterichindrance = True
params.getasa = True
params.getgaussiancurvature = True
params.getmolecularshapeindex = True
params.getdistancetoconvexhull = True
params.getvdw = True
params.getvdwstrain = True
params.getburiedvolume = True
params.getbondlength = True
params.getatomdistance = True
params.getbondangle = None
params.getdihedral = None
params.getbondmidpoint = True
params.getmomentdescriptors = ['geometric','sterimol']
params.getsolidanglecoverage = True 
params.getMoRSEweights= 'mass'  # Weights for MoRSE descriptors
params.getMoRSEbins = 10  # Number of bins for MoRSE descriptors
graph = MoleculeFeaturizerwithGeometry('CCCCC',params)
graph.run()
# Out:
# ic| self.GrabConformer: <bound method BaseFeaturizer.GrabConformer of <EGAT.src.graph.molecular.MoleculeGeometry.MoleculeFeaturizerwithGeometry object at 0x343402020>>
# ic| self.GrabGeometry: <bound method BaseFeaturizer.GrabGeometry of <EGAT.src.graph.molecular.MoleculeGeometry.MoleculeFeaturizerwithGeometry object at 0x343402020>>
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 686.42it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 112.19it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 204.34it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 700.77it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 967.21it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 721.62it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 1953.62it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 689.45it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2335.92it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 690.07it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2985.33it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 772.28it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2159.88it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1198.50it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2454.41it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 808.65it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2175.95it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1247.10it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2929.01it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 852.24it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2550.73it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1163.95it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2262.51it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1277.24it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2284.23it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1170.88it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 1891.80it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1059.25it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2388.34it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 774.63it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2694.38it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 675.50it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 4480.89it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 743.76it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 7442.61it/s]
# Processing bond 0 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 11573.69it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 10273.19it/s]
# Processing bond 1 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 72817.78it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 13774.88it/s]
# Processing bond 2 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 68534.38it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 8480.63it/s]
# Processing bond 3 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 47233.15it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 32686.50it/s]
# Processing bond 4 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 7505.91it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 7654.73it/s]
# Processing bond 5 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 61500.06it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 8233.74it/s]
# Processing bond 6 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 22121.86it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 15525.89it/s]
# Processing bond 7 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 30660.12it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 24211.78it/s]
# Processing bond 8 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 22919.69it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 11630.91it/s]
# Processing bond 9 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 19169.58it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 7817.44it/s]
# Processing bond 10 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 56833.39it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 15927.31it/s]
# Processing bond 11 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 13925.31it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 18643.11it/s]
# Processing bond 12 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 23696.63it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 27198.16it/s]
# Processing bond 13 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 4032.21it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 38874.44it/s]
# Processing bond 14 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 20164.92it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 17917.86it/s]
# Processing bond 15 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 61141.46it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 12547.41it/s]
# Processing bond 16 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 39643.71it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 12427.18it/s]
# Processing bond 17 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 9153.87it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 27659.93it/s]
# Processing bond 18 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 65741.44it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 35506.54it/s]
# Processing bond 19 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 69442.12it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 33813.43it/s]
# Processing bond 20 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 76818.75it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 25921.41it/s]
# Processing bond 21 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 81601.25it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 26993.33it/s]
# Processing bond 22 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 54330.36it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 28045.57it/s]
# Processing bond 23 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 84562.58it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 32279.73it/s]
# Processing bond 24 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 60262.99it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 35551.36it/s]
# Processing bond 25 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 69442.12it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 21708.21it/s]
# Processing bond 26 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 82891.38it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 29396.40it/s]
# Processing bond 27 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 89240.51it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 27586.38it/s]
# Processing bond 28 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 89240.51it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 16967.83it/s]
# Processing bond 29 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 60963.72it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 32686.50it/s]
# Processing bond 30 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 101311.69it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 29392.02it/s]
# Processing bond 31 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 106997.55it/s]

# %%
params.getclusteringcoeff = True
params.getclosenesscentrality = True
params.getdegreecentrality = True
params.getgraphdensity = True
params.getavgdegneighbors = True
params.getnodeclustering = True
params.getassortativity = True
params.getspectralradius = True
params.getdegreeentropy = True
params.getlocalbertzct = True
params.getcoulomb = True
params.getpagerank = True
params.getglobal = True
params.getshortestpath = 'all'
params.bias_walk = 'random'
params.num_walks = 10
params.getuniquewalks = True
params.getrandomwalk = True
params.getshortestpathcount = True
params.getcommonneighbors = 'all'
params.getglobaljaccard = True
params.getglobaladamicadar = True
params.getprefattachment = True
params.getkatz = True
params.getEigenvectorCentrality = True
params.getBetweennessCentralityCorrelation = True
params.getMinCutValue = True
params.getMaximumFlow = True
params.getLaplacianEigenvectorSimilarity = True
params.getFiedlerVectorSimilarity = True
params.getBetweennessCentralityOfPathways = True
params.getRingsInSharedPath = True
params.getfirstpassagetime = True
params.geteffectiveresistance = True
params.getSameAromaticSequence = True
params.getTopoOverlap = True
params.getEdgeClustering = True
params.getFormanCurve = True
params.global_fingerprint_type = 'Morgan'
params.global_similarity_metric = 'Tanimoto'
params.getLocalAtomicEnvironmentSimilarity = True
params.getsamefg = True
params.ct_method = 'spectral'
params.addhbonds = True
params.addcho = True
params.adddihydrogenbonds = True
params.addcationpi = True
params.addpipistack = True
params.addhalogenbonds = True
params.addmetallophilic = True
params.addelectrostatic = True
params.check_hbond = True
params.wt_adj_mat_by = None  # Options: 'bond_order', 'atomic_mass', 'valence', 'hybridization', 'coulomb', 'all'
params.rw_weight_by = None  # Options: 'atomic_mass', 'bond_order', 'hyb', 'valence', 'coulomb', 'all'
params.sp_box_size = None  # For periodic boundary conditions
params.hop_radius = 1  # For k-hop subgraph extraction
params.getrandomwalkcommutetime  = True
graph = MoleculeFeaturizerwithPadding('CCCCC',params)
graph.run()
# Out:
# ic| self.GrabConformer: <bound method BaseFeaturizer.GrabConformer of <EGAT.src.graph.molecular.MoleculeGlobal.MoleculeFeaturizerwithPadding object at 0x3434f3850>>
# ic| self.GrabGeometry: <bound method BaseFeaturizer.GrabGeometry of <EGAT.src.graph.molecular.MoleculeGlobal.MoleculeFeaturizerwithPadding object at 0x3434f3850>>
# ic| self.GrabConformer: <bound method BaseFeaturizer.GrabConformer of <EGAT.src.graph.molecular.MoleculeGlobal.MoleculeFeaturizerwithPadding object at 0x3434f3850>>
# ic| self.GrabGeometry: <bound method BaseFeaturizer.GrabGeometry of <EGAT.src.graph.molecular.MoleculeGlobal.MoleculeFeaturizerwithPadding object at 0x3434f3850>>
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 1814.55it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 678.45it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): nan
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 198.34it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 1169.05it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 803.12it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): nan
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 941.29it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 1538.47it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 720.52it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): nan
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 425.39it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2747.28it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 916.90it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): nan
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 594.42it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 103.28it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 684.64it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): nan
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 587.79it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2210.84it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 900.90it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): 0
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 710.88it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2093.43it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 780.64it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): 0
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 974.22it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2153.72it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1302.40it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): 0
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 1085.57it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2652.58it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 807.67it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): 0
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 1365.26it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2505.99it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1076.50it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): 0
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 666.19it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2520.42it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 800.12it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): 0
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 349.88it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 3855.06it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1287.61it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): 0
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 1109.69it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2386.48it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 809.75it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): 0
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 797.21it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2279.23it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 949.65it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): 0
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 1395.74it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2174.20it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1310.28it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): 0
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 1021.22it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2034.29it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 700.92it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): 0
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 418.95it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2675.01it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 784.15it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): 0
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 1481.32it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 11203.88it/s]
# ic| edge: [0, 1]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4140.79it/s]
# ic| edge: [0, 1]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6476.15it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 31846.90it/s]
# ic| edge: [0, 5]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7599.97it/s]
# ic| edge: [0, 5]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6316.36it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 29295.93it/s]
# ic| edge: [0, 6]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6041.32it/s]
# ic| edge: [0, 6]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6174.38it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 27878.98it/s]
# ic| edge: [0, 7]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6515.23it/s]
# ic| edge: [0, 7]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6375.44it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 36923.07it/s]
# ic| edge: [0, 1]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6699.34it/s]
# ic| edge: [0, 1]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7439.25it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 33836.64it/s]
# ic| edge: [1, 2]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7317.45it/s]
# ic| edge: [1, 2]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7549.46it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 29152.96it/s]
# ic| edge: [1, 8]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6477.69it/s]
# ic| edge: [1, 8]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7053.35it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 32702.77it/s]
# ic| edge: [1, 9]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6254.05it/s]
# ic| edge: [1, 9]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7365.39it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 27843.54it/s]
# ic| edge: [1, 2]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6756.62it/s]
# ic| edge: [1, 2]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6797.48it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 34082.35it/s]
# ic| edge: [2, 3]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7649.54it/s]
# ic| edge: [2, 3]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7443.82it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 36854.05it/s]
# ic| edge: [2, 10]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7268.19it/s]
# ic| edge: [2, 10]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6496.60it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 29484.34it/s]
# ic| edge: [2, 11]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6227.98it/s]
# ic| edge: [2, 11]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6475.38it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 28141.65it/s]
# ic| edge: [2, 3]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7019.30it/s]
# ic| edge: [2, 3]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 1232.57it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 4702.92it/s]
# ic| edge: [3, 4]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 1699.47it/s]
# ic| edge: [3, 4]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 655.72it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 3683.34it/s]
# ic| edge: [3, 12]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6247.24it/s]
# ic| edge: [3, 12]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 363.39it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 2796.12it/s]
# ic| edge: [3, 13]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 901.93it/s]
# ic| edge: [3, 13]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7099.73it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 30342.05it/s]
# ic| edge: [3, 4]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6508.62it/s]
# ic| edge: [3, 4]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4288.99it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 22003.83it/s]
# ic| edge: [4, 14]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3598.72it/s]
# ic| edge: [4, 14]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3689.55it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 29479.93it/s]
# ic| edge: [4, 15]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6381.78it/s]
# ic| edge: [4, 15]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 5057.36it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 27808.19it/s]
# ic| edge: [4, 16]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 5591.26it/s]
# ic| edge: [4, 16]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4145.99it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 26404.00it/s]
# ic| edge: [0, 5]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6411.80it/s]
# ic| edge: [0, 5]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6070.24it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 23429.08it/s]
# ic| edge: [0, 6]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6439.06it/s]
# ic| edge: [0, 6]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7499.10it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 32976.29it/s]
# ic| edge: [0, 7]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7327.77it/s]
# ic| edge: [0, 7]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6283.24it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 32412.41it/s]
# ic| edge: [1, 8]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6440.20it/s]
# ic| edge: [1, 8]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6101.83it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 25215.18it/s]
# ic| edge: [1, 9]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6283.24it/s]
# ic| edge: [1, 9]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7254.65it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 41484.07it/s]
# ic| edge: [2, 10]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6064.84it/s]
# ic| edge: [2, 10]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6461.57it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 34681.96it/s]
# ic| edge: [2, 11]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6521.07it/s]
# ic| edge: [2, 11]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7540.58it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 37117.73it/s]
# ic| edge: [3, 12]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7324.33it/s]
# ic| edge: [3, 12]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7025.18it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 34663.67it/s]
# ic| edge: [3, 13]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6652.75it/s]
# ic| edge: [3, 13]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 8100.12it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 20560.31it/s]
# ic| edge: [4, 14]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7602.61it/s]
# ic| edge: [4, 14]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7382.84it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 27517.07it/s]
# ic| edge: [4, 15]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6080.74it/s]
# ic| edge: [4, 15]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 5936.41it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 22401.40it/s]
# ic| edge: [4, 16]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6987.37it/s]
# ic| edge: [4, 16]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4761.05it/s]
# Processing global bonds (outer loop):   0%|          | 0/17 [00:00<?, ?it/s]ic| edge: [0, 2]
# ic| edge: [0, 2]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 20119.65it/s]
# Processing bond [0, 2] with edge [0, 2] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 77101.18it/s]
# ic| edge: [0, 2]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3044.87it/s]
# ic| edge: [0, 3]
# ic| edge: [0, 3]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 27390.90it/s]
# Processing bond [0, 3] with edge [0, 3] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 79437.58it/s]
# ic| edge: [0, 3]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 2935.84it/s]
# ic| edge: [0, 4]
# ic| edge: [0, 4]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 31064.02it/s]
# Processing bond [0, 4] with edge [0, 4] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 72565.81it/s]
# ic| edge: [0, 4]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3476.42it/s]
# ic| edge: [0, 8]
# ic| edge: [0, 8]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 45548.13it/s]
# Processing bond [0, 8] with edge [0, 8] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 57456.22it/s]
# ic| edge: [0, 8]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 1218.77it/s]
# ic| edge: [0, 9]
# ic| edge: [0, 9]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 6954.75it/s]
# Processing bond [0, 9] with edge [0, 9] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 4125.00it/s]
# ic| edge: [0, 9]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 1118.66it/s]
# ic| edge: [0, 10]
# ic| edge: [0, 10]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 43354.36it/s]
# Processing bond [0, 10] with edge [0, 10] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 59578.18it/s]
# ic| edge: [0, 10]
#
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 187.21it/s]
# ic| edge: [0, 11]
# ic| edge: [0, 11]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 35101.90it/s]
# Processing bond [0, 11] with edge [0, 11] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 64927.31it/s]
# ic| edge: [0, 11]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4095.23it/s]
# ic| edge: [0, 12]
# ic| edge: [0, 12]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 17510.42it/s]
# Processing bond [0, 12] with edge [0, 12] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 22623.00it/s]
# ic| edge: [0, 12]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3343.20it/s]
# ic| edge: [0, 13]
# ic| edge: [0, 13]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 25598.27it/s]
# Processing bond [0, 13] with edge [0, 13] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 43509.38it/s]
# ic| edge: [0, 13]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 2582.70it/s]
# ic| edge: [0, 14]
# ic| edge: [0, 14]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 25102.80it/s]
# Processing bond [0, 14] with edge [0, 14] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 68534.38it/s]
# ic| edge: [0, 14]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 2521.78it/s]
# ic| edge: [0, 15]
# ic| edge: [0, 15]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 27307.42it/s]
# Processing bond [0, 15] with edge [0, 15] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 62601.55it/s]
# ic| edge: [0, 15]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3662.90it/s]
# ic| edge: [0, 16]
# ic| edge: [0, 16]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 34230.30it/s]
# Processing bond [0, 16] with edge [0, 16] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 33825.03it/s]
# ic| edge: [0, 16]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3882.92it/s]
# Processing global bonds (outer loop):   6%|▌         | 1/17 [00:00<00:14,  1.14it/s]ic| edge: [1, 3]
# ic| edge: [1, 3]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 50702.75it/s]
# Processing bond [1, 3] with edge [1, 3] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 70611.18it/s]
# ic| edge: [1, 3]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3766.38it/s]
# ic| edge: [1, 4]
# ic| edge: [1, 4]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 41017.95it/s]
# Processing bond [1, 4] with edge [1, 4] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 45392.90it/s]
# ic| edge: [1, 4]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4144.73it/s]
# ic| edge: [1, 5]
# ic| edge: [1, 5]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 48916.20it/s]
# Processing bond [1, 5] with edge [1, 5] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 103819.41it/s]
# ic| edge: [1, 5]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4703.35it/s]
# ic| edge: [1, 6]
# ic| edge: [1, 6]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 47093.24it/s]
# Processing bond [1, 6] with edge [1, 6] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 32665.92it/s]
# ic| edge: [1, 6]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4316.84it/s]
# ic| edge: [1, 7]
# ic| edge: [1, 7]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 32937.73it/s]
# Processing bond [1, 7] with edge [1, 7] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 53773.13it/s]
# ic| edge: [1, 7]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3592.31it/s]
# ic| edge: [1, 10]
# ic| edge: [1, 10]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 34433.59it/s]
# Processing bond [1, 10] with edge [1, 10] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 72315.59it/s]
# ic| edge: [1, 10]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 5042.40it/s]
# ic| edge: [1, 11]
# ic| edge: [1, 11]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 51754.34it/s]
# Processing bond [1, 11] with edge [1, 11] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 43873.47it/s]
# ic| edge: [1, 11]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4780.25it/s]
# ic| edge: [1, 12]
# ic| edge: [1, 12]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 42892.14it/s]
# Processing bond [1, 12] with edge [1, 12] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 94466.31it/s]
# ic| edge: [1, 12]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3260.54it/s]
# ic| edge: [1, 13]
# ic| edge: [1, 13]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 39105.79it/s]
# Processing bond [1, 13] with edge [1, 13] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 62415.24it/s]
# ic| edge: [1, 13]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4286.80it/s]
# ic| edge: [1, 14]
# ic| edge: [1, 14]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 34129.55it/s]
# Processing bond [1, 14] with edge [1, 14] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 76818.75it/s]
# ic| edge: [1, 14]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 467.78it/s]
# ic| edge: [1, 15]
# ic| edge: [1, 15]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 34135.46it/s]
# Processing bond [1, 15] with edge [1, 15] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 69442.12it/s]
# ic| edge: [1, 15]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 2535.62it/s]
# ic| edge: [1, 16]
# ic| edge: [1, 16]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 16973.68it/s]
# Processing bond [1, 16] with edge [1, 16] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 10871.71it/s]
# ic| edge: [1, 16]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3546.52it/s]
# Processing global bonds (outer loop):  12%|█▏        | 2/17 [00:01<00:12,  1.17it/s]ic| edge: [2, 4]
# ic| edge: [2, 4]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 44429.18it/s]
# Processing bond [2, 4] with edge [2, 4] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 73584.28it/s]
# ic| edge: [2, 4]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3742.22it/s]
# ic| edge: [2, 5]
# ic| edge: [2, 5]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 30539.47it/s]
# Processing bond [2, 5] with edge [2, 5] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 32870.72it/s]
# ic| edge: [2, 5]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3362.27it/s]
# ic| edge: [2, 6]
# ic| edge: [2, 6]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 27486.38it/s]
# Processing bond [2, 6] with edge [2, 6] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 60090.32it/s]
# ic| edge: [2, 6]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 2427.64it/s]
# ic| edge: [2, 7]
# ic| edge: [2, 7]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 26875.57it/s]
# Processing bond [2, 7] with edge [2, 7] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 29086.71it/s]
# ic| edge: [2, 7]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 2933.87it/s]
# ic| edge: [2, 8]
# ic| edge: [2, 8]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 42149.30it/s]
# Processing bond [2, 8] with edge [2, 8] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 69212.94it/s]
# ic| edge: [2, 8]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3661.55it/s]
# ic| edge: [2, 9]
# ic| edge: [2, 9]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 33355.72it/s]
# Processing bond [2, 9] with edge [2, 9] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 70611.18it/s]
# ic| edge: [2, 9]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3791.66it/s]
# ic| edge: [2, 12]
# ic| edge: [2, 12]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 32637.80it/s]
# Processing bond [2, 12] with edge [2, 12] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 80659.69it/s]
# ic| edge: [2, 12]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4809.56it/s]
# ic| edge: [2, 13]
# ic| edge: [2, 13]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 40214.67it/s]
# Processing bond [2, 13] with edge [2, 13] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 53227.21it/s]
# ic| edge: [2, 13]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 5076.20it/s]
# ic| edge: [2, 14]
# ic| edge: [2, 14]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 32530.08it/s]
# Processing bond [2, 14] with edge [2, 14] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 29579.01it/s]
# ic| edge: [2, 14]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3238.65it/s]
# ic| edge: [2, 15]
# ic| edge: [2, 15]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 39696.39it/s]
# Processing bond [2, 15] with edge [2, 15] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 68534.38it/s]
# ic| edge: [2, 15]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3211.94it/s]
# ic| edge: [2, 16]
# ic| edge: [2, 16]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 52165.20it/s]
# Processing bond [2, 16] with edge [2, 16] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 21959.71it/s]
# ic| edge: [2, 16]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3451.01it/s]
# Processing global bonds (outer loop):  18%|█▊        | 3/17 [00:02<00:08,  1.57it/s]ic| edge: [3, 5]
# ic| edge: [3, 5]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 46680.63it/s]
# Processing bond [3, 5] with edge [3, 5] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 48433.07it/s]
# ic| edge: [3, 5]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3799.59it/s]
# ic| edge: [3, 6]
# ic| edge: [3, 6]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 45411.72it/s]
# Processing bond [3, 6] with edge [3, 6] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 59409.41it/s]
# ic| edge: [3, 6]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3131.43it/s]
# ic| edge: [3, 7]
# ic| edge: [3, 7]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 48198.60it/s]
# Processing bond [3, 7] with edge [3, 7] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 24643.38it/s]
# ic| edge: [3, 7]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 390.88it/s]
# ic| edge: [3, 8]
# ic| edge: [3, 8]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 4549.45it/s]
# Processing bond [3, 8] with edge [3, 8] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 3448.13it/s]
# ic| edge: [3, 8]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 323.15it/s]
# ic| edge: [3, 9]
# ic| edge: [3, 9]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 34915.39it/s]
# Processing bond [3, 9] with edge [3, 9] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 28886.39it/s]
# ic| edge: [3, 9]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3006.09it/s]
# ic| edge: [3, 10]
# ic| edge: [3, 10]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 39568.91it/s]
# Processing bond [3, 10] with edge [3, 10] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 87746.95it/s]
# ic| edge: [3, 10]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4442.94it/s]
# ic| edge: [3, 11]
# ic| edge: [3, 11]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 32664.84it/s]
# Processing bond [3, 11] with edge [3, 11] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 36472.21it/s]
# ic| edge: [3, 11]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3775.90it/s]
# ic| edge: [3, 14]
# ic| edge: [3, 14]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 36184.34it/s]
# Processing bond [3, 14] with edge [3, 14] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 66788.28it/s]
# ic| edge: [3, 14]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3455.06it/s]
# ic| edge: [3, 15]
# ic| edge: [3, 15]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 30620.11it/s]
# Processing bond [3, 15] with edge [3, 15] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 28886.39it/s]
# ic| edge: [3, 15]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4333.48it/s]
# ic| edge: [3, 16]
# ic| edge: [3, 16]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 33692.07it/s]
# Processing bond [3, 16] with edge [3, 16] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 56073.58it/s]
# ic| edge: [3, 16]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3909.23it/s]
# Processing global bonds (outer loop):  24%|██▎       | 4/17 [00:02<00:08,  1.45it/s]ic| edge: [4, 5]
# ic| edge: [4, 5]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 32481.84it/s]
# Processing bond [4, 5] with edge [4, 5] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 69672.82it/s]
# ic| edge: [4, 5]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3380.62it/s]
# ic| edge: [4, 6]
# ic| edge: [4, 6]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 24865.32it/s]
# Processing bond [4, 6] with edge [4, 6] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 49932.19it/s]
# ic| edge: [4, 6]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 2905.42it/s]
# ic| edge: [4, 7]
# ic| edge: [4, 7]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 33293.75it/s]
# Processing bond [4, 7] with edge [4, 7] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 69442.12it/s]
# ic| edge: [4, 7]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 2689.58it/s]
# ic| edge: [4, 8]
# ic| edge: [4, 8]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 34971.14it/s]
# Processing bond [4, 8] with edge [4, 8] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 89240.51it/s]
# ic| edge: [4, 8]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3992.67it/s]
# ic| edge: [4, 9]
# ic| edge: [4, 9]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 48116.25it/s]
# Processing bond [4, 9] with edge [4, 9] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 43509.38it/s]
# ic| edge: [4, 9]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3976.08it/s]
# ic| edge: [4, 10]
# ic| edge: [4, 10]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 27216.94it/s]
# Processing bond [4, 10] with edge [4, 10] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 64927.31it/s]
# ic| edge: [4, 10]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4811.25it/s]
# ic| edge: [4, 11]
# ic| edge: [4, 11]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 35551.36it/s]
# Processing bond [4, 11] with edge [4, 11] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 22944.77it/s]
# ic| edge: [4, 11]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4333.99it/s]
# ic| edge: [4, 12]
# ic| edge: [4, 12]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 37851.82it/s]
# Processing bond [4, 12] with edge [4, 12] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 25145.71it/s]
# ic| edge: [4, 12]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6015.66it/s]
# ic| edge: [4, 13]
# ic| edge: [4, 13]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 33594.46it/s]
# Processing bond [4, 13] with edge [4, 13] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 52038.51it/s]
# ic| edge: [4, 13]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 5316.75it/s]
# Processing global bonds (outer loop):  29%|██▉       | 5/17 [00:03<00:06,  1.81it/s]ic| edge: [5, 6]
# ic| edge: [5, 6]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 4443.22it/s]
# Processing bond [5, 6] with edge [5, 6] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 11335.96it/s]
# ic| edge: [5, 6]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 799.78it/s]
# ic| edge: [5, 7]
# ic| edge: [5, 7]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 3642.30it/s]
# Processing bond [5, 7] with edge [5, 7] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 5375.93it/s]
# ic| edge: [5, 7]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 487.77it/s]
# ic| edge: [5, 8]
# ic| edge: [5, 8]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 3449.81it/s]
# Processing bond [5, 8] with edge [5, 8] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 17787.55it/s]
# ic| edge: [5, 8]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4153.41it/s]
# ic| edge: [5, 9]
# ic| edge: [5, 9]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 10366.11it/s]
# Processing bond [5, 9] with edge [5, 9] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 52560.20it/s]
# ic| edge: [5, 9]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4421.14it/s]
# ic| edge: [5, 10]
# ic| edge: [5, 10]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 27471.05it/s]
# Processing bond [5, 10] with edge [5, 10] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 58254.22it/s]
# ic| edge: [5, 10]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4730.49it/s]
# ic| edge: [5, 11]
# ic| edge: [5, 11]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 33048.16it/s]
# Processing bond [5, 11] with edge [5, 11] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 53227.21it/s]
# ic| edge: [5, 11]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4648.02it/s]
# ic| edge: [5, 12]
# ic| edge: [5, 12]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 30323.38it/s]
# Processing bond [5, 12] with edge [5, 12] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 55627.37it/s]
# ic| edge: [5, 12]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 2916.84it/s]
# ic| edge: [5, 13]
# ic| edge: [5, 13]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 47421.77it/s]
# Processing bond [5, 13] with edge [5, 13] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 80659.69it/s]
# ic| edge: [5, 13]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3629.14it/s]
# ic| edge: [5, 14]
# ic| edge: [5, 14]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 32637.80it/s]
# Processing bond [5, 14] with edge [5, 14] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 65128.94it/s]
# ic| edge: [5, 14]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3424.67it/s]
# ic| edge: [5, 15]
# ic| edge: [5, 15]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 28093.53it/s]
# Processing bond [5, 15] with edge [5, 15] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 76818.75it/s]
# ic| edge: [5, 15]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3557.16it/s]
# ic| edge: [5, 16]
# ic| edge: [5, 16]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 37563.32it/s]
# Processing bond [5, 16] with edge [5, 16] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 63550.06it/s]
# ic| edge: [5, 16]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3128.46it/s]
# Processing global bonds (outer loop):  35%|███▌      | 6/17 [00:04<00:07,  1.54it/s]ic| edge: [6, 7]
# ic| edge: [6, 7]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 35360.05it/s]
# Processing bond [6, 7] with edge [6, 7] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 90785.80it/s]
# ic| edge: [6, 7]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 5635.17it/s]
# ic| edge: [6, 8]
# ic| edge: [6, 8]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 36860.94it/s]
# Processing bond [6, 8] with edge [6, 8] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 69212.94it/s]
# ic| edge: [6, 8]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 5100.17it/s]
# ic| edge: [6, 9]
# ic| edge: [6, 9]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 32080.11it/s]
# Processing bond [6, 9] with edge [6, 9] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 56833.39it/s]
# ic| edge: [6, 9]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 5191.71it/s]
# ic| edge: [6, 10]
# ic| edge: [6, 10]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 28694.66it/s]
# Processing bond [6, 10] with edge [6, 10] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 93206.76it/s]
# ic| edge: [6, 10]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4480.36it/s]
# ic| edge: [6, 11]
# ic| edge: [6, 11]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 41934.12it/s]
# Processing bond [6, 11] with edge [6, 11] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 61680.94it/s]
# ic| edge: [6, 11]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4278.39it/s]
# ic| edge: [6, 12]
# ic| edge: [6, 12]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 38714.12it/s]
# Processing bond [6, 12] with edge [6, 12] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 71331.70it/s]
# ic| edge: [6, 12]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4139.53it/s]
# ic| edge: [6, 13]
# ic| edge: [6, 13]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 8657.16it/s]
# Processing bond [6, 13] with edge [6, 13] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 10438.79it/s]
# ic| edge: [6, 13]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 502.32it/s]
# ic| edge: [6, 14]
# ic| edge: [6, 14]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 4180.78it/s]
# Processing bond [6, 14] with edge [6, 14] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 2274.08it/s]
# ic| edge: [6, 14]
#
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 168.42it/s]
# ic| edge: [6, 15]
# ic| edge: [6, 15]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 35822.69it/s]
# Processing bond [6, 15] with edge [6, 15] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 68534.38it/s]
# ic| edge: [6, 15]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3477.42it/s]
# ic| edge: [6, 16]
# ic| edge: [6, 16]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 32080.11it/s]
# Processing bond [6, 16] with edge [6, 16] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 89240.51it/s]
# ic| edge: [6, 16]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 2488.01it/s]
# Processing global bonds (outer loop):  41%|████      | 7/17 [00:04<00:07,  1.43it/s]ic| edge: [7, 8]
# ic| edge: [7, 8]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 30478.09it/s]
# Processing bond [7, 8] with edge [7, 8] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 56375.05it/s]
# ic| edge: [7, 8]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4453.64it/s]
# ic| edge: [7, 9]
# ic| edge: [7, 9]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 32546.19it/s]
# Processing bond [7, 9] with edge [7, 9] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 59578.18it/s]
# ic| edge: [7, 9]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 5293.01it/s]
# ic| edge: [7, 10]
# ic| edge: [7, 10]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 28677.96it/s]
# Processing bond [7, 10] with edge [7, 10] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 33554.43it/s]
# ic| edge: [7, 10]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4290.34it/s]
# ic| edge: [7, 11]
# ic| edge: [7, 11]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 38434.84it/s]
# Processing bond [7, 11] with edge [7, 11] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 54330.36it/s]
# ic| edge: [7, 11]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4638.14it/s]
# ic| edge: [7, 12]
# ic| edge: [7, 12]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 39696.39it/s]
# Processing bond [7, 12] with edge [7, 12] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 71575.15it/s]
# ic| edge: [7, 12]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3330.34it/s]
# ic| edge: [7, 13]
# ic| edge: [7, 13]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 49944.84it/s]
# Processing bond [7, 13] with edge [7, 13] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 73584.28it/s]
# ic| edge: [7, 13]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4177.27it/s]
# ic| edge: [7, 14]
# ic| edge: [7, 14]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 30758.67it/s]
# Processing bond [7, 14] with edge [7, 14] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 83220.32it/s]
# ic| edge: [7, 14]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3388.18it/s]
# ic| edge: [7, 15]
# ic| edge: [7, 15]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 48304.90it/s]
# Processing bond [7, 15] with edge [7, 15] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 65741.44it/s]
# ic| edge: [7, 15]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 2647.60it/s]
# ic| edge: [7, 16]
# ic| edge: [7, 16]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 42892.14it/s]
# Processing bond [7, 16] with edge [7, 16] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 58743.75it/s]
# ic| edge: [7, 16]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 2977.45it/s]
# Processing global bonds (outer loop):  47%|████▋     | 8/17 [00:05<00:05,  1.76it/s]ic| edge: [8, 9]
# ic| edge: [8, 9]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 39458.02it/s]
# Processing bond [8, 9] with edge [8, 9] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 46707.17it/s]
# ic| edge: [8, 9]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6074.64it/s]
# ic| edge: [8, 10]
# ic| edge: [8, 10]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 28450.32it/s]
# Processing bond [8, 10] with edge [8, 10] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 45100.04it/s]
# ic| edge: [8, 10]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 5030.77it/s]
# ic| edge: [8, 11]
# ic| edge: [8, 11]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 33520.20it/s]
# Processing bond [8, 11] with edge [8, 11] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 72565.81it/s]
# ic| edge: [8, 11]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4675.32it/s]
# ic| edge: [8, 12]
# ic| edge: [8, 12]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 42230.57it/s]
# Processing bond [8, 12] with edge [8, 12] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 66576.25it/s]
# ic| edge: [8, 12]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4370.47it/s]
# ic| edge: [8, 13]
# ic| edge: [8, 13]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 4908.55it/s]
# Processing bond [8, 13] with edge [8, 13] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 15984.39it/s]
# ic| edge: [8, 13]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 1096.68it/s]
# ic| edge: [8, 14]
# ic| edge: [8, 14]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 8404.70it/s]
# Processing bond [8, 14] with edge [8, 14] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 3209.11it/s]
# ic| edge: [8, 14]
#
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 170.85it/s]
# ic| edge: [8, 15]
# ic| edge: [8, 15]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 31800.66it/s]
# Processing bond [8, 15] with edge [8, 15] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 54330.36it/s]
# ic| edge: [8, 15]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3665.12it/s]
# ic| edge: [8, 16]
# ic| edge: [8, 16]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 25678.30it/s]
# Processing bond [8, 16] with edge [8, 16] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 74898.29it/s]
# ic| edge: [8, 16]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3113.46it/s]
# Processing global bonds (outer loop):  53%|█████▎    | 9/17 [00:05<00:05,  1.59it/s]ic| edge: [9, 10]
# ic| edge: [9, 10]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 41562.78it/s]
# Processing bond [9, 10] with edge [9, 10] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 36663.50it/s]
# ic| edge: [9, 10]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4602.51it/s]
# ic| edge: [9, 11]
# ic| edge: [9, 11]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 26165.69it/s]
# Processing bond [9, 11] with edge [9, 11] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 65741.44it/s]
# ic| edge: [9, 11]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4122.32it/s]
# ic| edge: [9, 12]
# ic| edge: [9, 12]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 33378.31it/s]
# Processing bond [9, 12] with edge [9, 12] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 55480.21it/s]
# ic| edge: [9, 12]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3592.31it/s]
# ic| edge: [9, 13]
# ic| edge: [9, 13]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 34236.24it/s]
# Processing bond [9, 13] with edge [9, 13] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 57456.22it/s]
# ic| edge: [9, 13]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4445.84it/s]
# ic| edge: [9, 14]
# ic| edge: [9, 14]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 32127.17it/s]
# Processing bond [9, 14] with edge [9, 14] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 66788.28it/s]
# ic| edge: [9, 14]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 2877.06it/s]
# ic| edge: [9, 15]
# ic| edge: [9, 15]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 36628.07it/s]
# Processing bond [9, 15] with edge [9, 15] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 62415.24it/s]
# ic| edge: [9, 15]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3609.20it/s]
# ic| edge: [9, 16]
# ic| edge: [9, 16]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 32012.39it/s]
# Processing bond [9, 16] with edge [9, 16] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 71331.70it/s]
# ic| edge: [9, 16]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 2415.91it/s]
# Processing global bonds (outer loop):  59%|█████▉    | 10/17 [00:06<00:03,  1.98it/s]ic| edge: [10, 11]
# ic| edge: [10, 11]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 40313.35it/s]
# Processing bond [10, 11] with edge [10, 11] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 48884.66it/s]
# ic| edge: [10, 11]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6090.58it/s]
# ic| edge: [10, 12]
# ic| edge: [10, 12]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 40654.21it/s]
# Processing bond [10, 12] with edge [10, 12] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 31068.92it/s]
# ic| edge: [10, 12]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3810.74it/s]
# ic| edge: [10, 13]
# ic| edge: [10, 13]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 30544.20it/s]
# Processing bond [10, 13] with edge [10, 13] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 65741.44it/s]
# ic| edge: [10, 13]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 5388.74it/s]
# ic| edge: [10, 14]
# ic| edge: [10, 14]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 29282.87it/s]
# Processing bond [10, 14] with edge [10, 14] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 39053.11it/s]
# ic| edge: [10, 14]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4109.89it/s]
# ic| edge: [10, 15]
# ic| edge: [10, 15]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 32849.91it/s]
# Processing bond [10, 15] with edge [10, 15] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 63167.23it/s]
# ic| edge: [10, 15]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3696.30it/s]
# ic| edge: [10, 16]
# ic| edge: [10, 16]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 31780.15it/s]
# Processing bond [10, 16] with edge [10, 16] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 57456.22it/s]
# ic| edge: [10, 16]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 360.31it/s]
# Processing global bonds (outer loop):  65%|██████▍   | 11/17 [00:06<00:02,  2.27it/s]ic| edge: [11, 12]
# ic| edge: [11, 12]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 4871.43it/s]
# Processing bond [11, 12] with edge [11, 12] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 9058.97it/s]
# ic| edge: [11, 12]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 305.33it/s]
# ic| edge: [11, 13]
# ic| edge: [11, 13]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 6105.44it/s]
# Processing bond [11, 13] with edge [11, 13] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 17050.02it/s]
# ic| edge: [11, 13]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4044.80it/s]
# ic| edge: [11, 14]
# ic| edge: [11, 14]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 29599.44it/s]
# Processing bond [11, 14] with edge [11, 14] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 64133.09it/s]
# ic| edge: [11, 14]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 1430.13it/s]
# ic| edge: [11, 15]
# ic| edge: [11, 15]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 31693.29it/s]
# Processing bond [11, 15] with edge [11, 15] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 91180.52it/s]
# ic| edge: [11, 15]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3989.02it/s]
# ic| edge: [11, 16]
# ic| edge: [11, 16]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 27989.82it/s]
# Processing bond [11, 16] with edge [11, 16] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 40021.98it/s]
# ic| edge: [11, 16]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3088.59it/s]
# Processing global bonds (outer loop):  71%|███████   | 12/17 [00:06<00:02,  2.12it/s]ic| edge: [12, 13]
# ic| edge: [12, 13]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 28503.80it/s]
# Processing bond [12, 13] with edge [12, 13] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 47662.55it/s]
# ic| edge: [12, 13]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6152.43it/s]
# ic| edge: [12, 14]
# ic| edge: [12, 14]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 32773.45it/s]
# Processing bond [12, 14] with edge [12, 14] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 86302.55it/s]
# ic| edge: [12, 14]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4628.10it/s]
# ic| edge: [12, 15]
# ic| edge: [12, 15]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 39074.78it/s]
# Processing bond [12, 15] with edge [12, 15] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 21183.35it/s]
# ic| edge: [12, 15]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3977.38it/s]
# ic| edge: [12, 16]
# ic| edge: [12, 16]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 35366.40it/s]
# Processing bond [12, 16] with edge [12, 16] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 81920.00it/s]
# ic| edge: [12, 16]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4071.38it/s]
# Processing global bonds (outer loop):  76%|███████▋  | 13/17 [00:07<00:01,  2.78it/s]ic| edge: [13, 14]
# ic| edge: [13, 14]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 32981.81it/s]
# Processing bond [13, 14] with edge [13, 14] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 58254.22it/s]
# ic| edge: [13, 14]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3553.92it/s]
# ic| edge: [13, 15]
# ic| edge: [13, 15]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 41457.89it/s]
# Processing bond [13, 15] with edge [13, 15] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 66788.28it/s]
# ic| edge: [13, 15]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3968.27it/s]
# ic| edge: [13, 16]
# ic| edge: [13, 16]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 33663.30it/s]
# Processing bond [13, 16] with edge [13, 16] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 53773.13it/s]
# ic| edge: [13, 16]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 5107.82it/s]
# Processing global bonds (outer loop):  82%|████████▏ | 14/17 [00:07<00:00,  3.49it/s]ic| edge: [14, 15]
# ic| edge: [14, 15]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 29706.49it/s]
# Processing bond [14, 15] with edge [14, 15] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 64133.09it/s]
# ic| edge: [14, 15]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6276.73it/s]
# ic| edge: [14, 16]
# ic| edge: [14, 16]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 33333.16it/s]
# Processing bond [14, 16] with edge [14, 16] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 76818.75it/s]
# ic| edge: [14, 16]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6127.54it/s]
# ic| edge: [15, 16]
# ic| edge: [15, 16]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 28226.27it/s]
# Processing bond [15, 16] with edge [15, 16] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 62601.55it/s]
# ic| edge: [15, 16]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 5391.94it/s]
# Processing global bonds (outer loop): 100%|██████████| 17/17 [00:07<00:00,  2.34it/s]

# %%
# Define a perfectly atom-mapped reaction SMILES with hydrogens explicitly mapped, including hydrogens in CH3
reaction_smiles = "[H:8][C:1]([H:9])([H:10])[C:2](=[O:3])[O:4][H:5].[O:6][H:7]>>[H:8][C:1]([H:9])([H:10])[C:2](=[O:3])[O:6][H:7]"

# Create an instance of BaseReactionFeaturizer
reaction_featurizer = BaseReactionFeaturizer(reaction_smiles, params)
inspect(reaction_featurizer, methods=True)
# Out:
# ╭───────────────────────── <class 'EGAT.src.graph.base.reaction.BaseReactionFeaturizer'> ─────────────────────────╮
# │ ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────╮ │
# │ │ <EGAT.src.graph.base.reaction.BaseReactionFeaturizer object at 0x3434f2470>                                 │ │
# │ ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                                 │
# │              denotation = '>>'                                                                                  │
# │            elementcheck = False                                                                                 │
# │                  params = GraphParams(getradical='RDKit', stereo_full=False, acidbase='Lewis')                  │
# │                 product = <EGAT.src.graph.base.base.BaseFeaturizer object at 0x343403e50>                       │
# │                reactant = <EGAT.src.graph.base.base.BaseFeaturizer object at 0x3434f3c70>                       │
# │                reaction = '[H:8][C:1]([H:9])([H:10])[C:2](=[O:3])[O:4][H:5].[O:6][H:7]>>[H:8][C:1]([H:9])([H:1… │
# │             AddHMapping = def AddHMapping(smi):                                                                 │
# │          basefeaturizer = class basefeaturizer(smiles, arguments):                                              │
# │ CheckElementConsistency = def CheckElementConsistency():                                                        │
# │            IsAtomMapped = def IsAtomMapped(smi):                                                                │
# │          MapviaAAMUtils = def MapviaAAMUtils(r, p):                                                             │
# │       MapviaLocalMapper = def MapviaLocalMapper(r, p):                                                          │
# │              MapviaOB2D = def MapviaOB2D():                                                                     │
# │              MapviaOB3D = def MapviaOB3D():                                                                     │
# │             MapviaRDKit = def MapviaRDKit():                                                                    │
# │         MapviaRXNMapper = def MapviaRXNMapper(r, p):                                                            │
# │ ReactiveBondInformation = def ReactiveBondInformation():                                                        │
# │       SetFeaturesToNone = def SetFeaturesToNone():                                                              │
# │         SetupFeaturizer = def SetupFeaturizer():                                                                │
# │ SplitandCheckForMapping = def SplitandCheckForMapping(denotation):                                              │
# │        StripAtomMapping = def StripAtomMapping(smi):                                                            │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
from EGAT.src.graph.reaction.helper import ReactionHelper
reaction_helper = ReactionHelper(reaction_smiles, params,BaseFeaturizer)
inspect(reaction_helper, methods=True)
# Out:
# ╭──────────────────────────── <class 'EGAT.src.graph.reaction.helper.ReactionHelper'> ────────────────────────────╮
# │ ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────╮ │
# │ │ <EGAT.src.graph.reaction.helper.ReactionHelper object at 0x3454823b0>                                       │ │
# │ ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                                 │
# │                      denotation = '>>'                                                                          │
# │                    elementcheck = False                                                                         │
# │                          params = GraphParams(getradical='RDKit', stereo_full=False, acidbase='Lewis')          │
# │                         product = <EGAT.src.graph.base.base.BaseFeaturizer object at 0x343051390>               │
# │                        reactant = <EGAT.src.graph.base.base.BaseFeaturizer object at 0x3457d3dc0>               │
# │                        reaction = '[H:8][C:1]([H:9])([H:10])[C:2](=[O:3])[O:4][H:5].[O:6][H:7]>>[H:8][C:1]([H:… │
# │                 AcidBaseSitesBO = def AcidBaseSitesBO():                                                        │
# │              AcidBaseSitesLewis = def AcidBaseSitesLewis():                                                     │
# │                 AddAtomFunction = def AddAtomFunction(ind, fcn, object):                                        │
# │                 AddBondFunction = def AddBondFunction(edge, ind, fcn):                                          │
# │                     AddHMapping = def AddHMapping(smi):                                                         │
# │   AtomicNeighborhoodChangeRatio = def AtomicNeighborhoodChangeRatio(atom):                                      │
# │             AtomicValencyChange = def AtomicValencyChange(atom):                                                │
# │                  basefeaturizer = class basefeaturizer(smiles, arguments):                                      │
# │                  BondChangeInfo = def BondChangeInfo(edge, ind):                                                │
# │  BondConnectivityPathDifference = def BondConnectivityPathDifference(edge):                                     │
# │          BondNeighborhoodChange = def BondNeighborhoodChange(edge):                                             │
# │                 BondOrderChange = def BondOrderChange(edge):                                                    │
# │         BondParticipationDegree = def BondParticipationDegree(edge):                                            │
# │             BondPathOrderChange = def BondPathOrderChange(edge):                                                │
# │    BRICSBondFormationLikelihood = def BRICSBondFormationLikelihood(edge):                                       │
# │             BRICSBondRoleChange = def BRICSBondRoleChange(edge):                                                │
# │   BRICSFragmentationConsistency = def BRICSFragmentationConsistency(edge):                                      │
# │     ChangeInAtomicHybridization = def ChangeInAtomicHybridization(atom):                                        │
# │                         Charges = def Charges():                                                                │
# │         CheckElementConsistency = def CheckElementConsistency():                                                │
# │                    CheckMapping = def CheckMapping(ind):                                                        │
# │       CommonNeighborCountChange = def CommonNeighborCountChange(edge):                                          │
# │      ConnectivityPathDifference = def ConnectivityPathDifference(edge):                                         │
# │               CreateAtomMapping = def CreateAtomMapping():                                                      │
# │ DegreeCentralityOfChangingAtoms = def DegreeCentralityOfChangingAtoms(atom):                                    │
# │        DistanceFromReactingAtom = def DistanceFromReactingAtom(ind):                                            │
# │        DistanceFromReactingBond = def DistanceFromReactingBond(edge):                                           │
# │         ElectronFlowCorrelation = def ElectronFlowCorrelation(edge):                                            │
# │                            Eneg = def Eneg():                                                                   │
# │                   GenerateEdges = def GenerateEdges():                                                          │
# │                   GrabConformer = def GrabConformer(id=1):                                                      │
# │                    GrabGeometry = def GrabGeometry(id=1):                                                       │
# │                InitializeAddons = def InitializeAddons():                                                       │
# │                    IsAtomMapped = def IsAtomMapped(smi):                                                        │
# │         LocalBondOrderSumChange = def LocalBondOrderSumChange(atom):                                            │
# │                  MapviaAAMUtils = def MapviaAAMUtils(r, p):                                                     │
# │               MapviaLocalMapper = def MapviaLocalMapper(r, p):                                                  │
# │                      MapviaOB2D = def MapviaOB2D():                                                             │
# │                      MapviaOB3D = def MapviaOB3D():                                                             │
# │                     MapviaRDKit = def MapviaRDKit():                                                            │
# │                 MapviaRXNMapper = def MapviaRXNMapper(r, p):                                                    │
# │               MatrixDescriptors = def MatrixDescriptors():                                                      │
# │            NeighboringReactives = def NeighboringReactives(adj_mat, ind):                                       │
# │               OldBondChangeInfo = def OldBondChangeInfo(edge):                                                  │
# │            OxidationOrReduction = def OxidationOrReduction(atom):                                               │
# │                        Polarity = def Polarity():                                                               │
# │                        Radicals = def Radicals():                                                               │
# │                RandomWalkChange = def RandomWalkChange(edge):                                                   │
# │         ReactiveBondInformation = def ReactiveBondInformation():                                                │
# │             ReactiveGraphSepMat = def ReactiveGraphSepMat():                                                    │
# │              ReactivityDistance = def ReactivityDistance(edge):                                                 │
# │                           Rings = def Rings():                                                                  │
# │                    Rotatability = def Rotatability():                                                           │
# │               SetFeaturesToNone = def SetFeaturesToNone():                                                      │
# │                 SetupFeaturizer = def SetupFeaturizer():                                                        │
# │     SharedFunctionalGroupChange = def SharedFunctionalGroupChange(edge):                                        │
# │              ShortestPathChange = def ShortestPathChange(edge):                                                 │
# │    ShortestPathChangeAcrossBond = def ShortestPathChangeAcrossBond(edge):                                       │
# │         SplitandCheckForMapping = def SplitandCheckForMapping(denotation):                                      │
# │                      Stereochem = def Stereochem():                                                             │
# │                StripAtomMapping = def StripAtomMapping(smi):                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
from EGAT.src.graph.reaction.Reaction import ReactionFeaturizer 
reaction_featurizer = ReactionFeaturizer(reaction_smiles, params)
reaction_featurizer.reactant
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 from EGAT.src.graph.reaction.Reaction import ReactionFeaturizer
# ----> 2 reaction_featurizer = ReactionFeaturizer(reaction_smiles, params)
#       3 reaction_featurizer.reactant
#
# File ~/Documents/GitHub/EGAT/src/graph/reaction/Reaction.py:18, in ReactionFeaturizer.__init__(self, reaction_smiles, arguments, denotation)
#      17 def __init__(self,reaction_smiles,arguments,denotation='>>'):
# ---> 18     super(reaction_smiles, arguments,denotation,ReactionComponentFeaturizer).__init__()
#
# TypeError: super() takes at most 2 arguments (4 given)
