# %%
import sys
sys.path.append("/Users/svaddadi/Documents/GitHub/")
import EGAT
from EGAT import src
from EGAT.src.graph.molecular.Molecule import MoleculeFeaturizer
from EGAT.src.graph.molecular.MoleculeGeometry import MoleculeFeaturizerwithGeometry
from EGAT.src.graph.molecular.MoleculeGlobal import MoleculeFeaturizerwithPadding
from EGAT.src.params.graph import GraphParams
from EGAT.src.graph.reaction.helper import ReactionHelper
from EGAT.src.graph.reaction.Reaction import ReactionFeaturizer 
from EGAT.src.graph.reaction.ReactionGeometry import ReactionFeaturizerwithGeometry
from EGAT.src.graph.reaction.ReactionGlobal import ReactionFeaturizerwithPadding
from EGAT.src.graph.base.base import BaseReactionParams,BaseFeaturizer
from EGAT.src.graph.base.reaction import BaseReactionFeaturizer
from EGAT.src.graph.base.component import BaseReactionComponentFeaturizer
from rich import inspect
from rich.console import Console
# Out:
# WARNING: Ignoring invalid distribution -dkit (/opt/anaconda3/envs/EGAT_CPU/lib/python3.10/site-packages)

# %%
def get_dir_to_txt_file(object,filename):
    """
    Get the directory of the txt file
    """
    # Create a Console that writes to a file
    with open(filename, "w") as file:
        console = Console(file=file)
        inspect(object, console=console)

'''
params = BaseReactionParasms()
params.acidbase = 'BL'
params.getradical = 'RDKit'
params.stereo_full = True
smiles = "CC(=O)C1=CC=C(C=C1)C(=O)O"

graph = BaseFeaturizer(smiles,params)
get_dir_to_txt_file(graph,'Base.txt')

graph= BaseReactionComponentFeaturizer(smiles,params)
get_dir_to_txt_file(graph,'BaseReaction.txt')
'''
params = GraphParams()
# This is the way to set the parameters if you want explicit Acid-Base Information
params.acidbase = 'Lewis'
params.getacidbaseinfo = True
# This is the way to get radicals
# Note: For YARP,  YARP can give multiple smiles based on the resonance structure. The way we handle this is by obtaining x different graphs for the same y.
# With that, we would need to change the dataloader to handle such cases as it also happens with the conformational sampling. 
params.getradical = 'RDKit'
# This is the way to get spiro and brdgehead information. 
params.getspiro = True
params.getbridgehead = True
# This is the way to get fused ring information.
params.getfusedinformation = True
# This is the way to get rotatable bond information.
params.getrotatablebonds = True
# This is the way to get gasteiger charges.
params.charge = 'Gasteiger'
# This is the way to get BRICS Decomposition locations. 
params.getbrics = True
params.checkbricsbond = True 
# This is the way to get Electronegativity locations. 
params.getelectronegativity = True
# This is the way to get the bond dipoles.
params.getdipole = True
# This is the way to get the sigma and pi electrons.
params.getpielectrons = True
params.getsigmaelectrons = True
# This is the way to get the intrinsic state.
params.getintrinsicstate = True
# This is the way to get the eta and beta values.
params.getetabeta = True
# This is the way to get the ionization potential.
params.getionizationpotential = True
params.getionizationpotentialpooled = True
# This get core electrons
params.getcoreelectrons = True
# this gets the ramification number. 
params.getramificationnumber = True
params.getjazzydelta=  True
params.getjazzyfe = True
params.getlocantcount=True
params.getpolarity = True
params.threshold = 10.0
params.covalentnumber = "exp"
params.ps_size = (1.0, 1.5)
params.kallisto_thresholdCN = 10.0
params.kallisto_thresholdBond = 0.5
params.vdw_scale = 1.0
params.vdwtype = "truhlar"
params.getCN = True
params.getPS = True
params.getAPC = True
params.getvdwkallisto = True
params.getAP = True
params.useabc = 'reg'
params.useabs = 'gg'
params.getbarysz = True
params.getats = 'ATS'
params.getdetour = True
params.getburdenmat = 'reg'
params.burdenweight = 'reg'
params.getpropsrelativetocarbon = False #Needs Work
params.getvertexdistancedegree = True
params.getbalabanbondfactor = True
params.getsuperdentic = True
params.geteccentricity = True
params.getschultz = True
params.getgutman = True
params.getxui = True
params.gethorary = True
params.getmohar = 'laplacian'
params.gethp = True
params.getcorecount = True
params.getvem = True
params.getetacomposite = True
params.getetapsi = True
params.getgravity = True
params.getzagreb = 2
params.getharmonic = True
params.getsombor = True
params.getrandic = True
params.getnirmala = True
params.getsoss = True
params.getaugmentedgraphattributes = True
params.gethyperbolic = True
params.getaugzagreb = True
params.getklein = True
params.gethyperwiener = True
params.getwiener = True
params.gethdsa = True
params.getets = True
params.getinformationcontent = 0
params.getweightedinformationcontent = 0
params.getmoleculardistanceedge = True
params.gettopocharge = 3
params.getSMR = ['Li', 'logPregion','Ri']
params.getMoRSE = 'cos'
params.getchi = 3
params.getedgewiener = True
params.getvertexadjacency = True
params.getTPSA = True
params.getASA = True
params.LogS = True
params.getEstate = 'all'
params.getchivalence = 3
params.MDEvalences = [1, 1]
params.MDEreference = 'C'
params.mohar = 'unnormalized'
params.getvewi = True
params.getvewibyorder = 3
params.getedgewienerbyorder = 3
params.IC_weight = 'mass'
params.getresonance = True
params.conformer.generator = 'RDKit'
params.conformer.nconfs = 1
params.getsterimol = True
params.local_cutoff = 4.0
params.use_vdw = True
params.removecoordinationinfo = True
params.getdistancetocenterofmass = True
params.getsterichindrance = True
params.getasa = True
params.getgaussiancurvature = True
params.getmolecularshapeindex = True
params.getdistancetoconvexhull = True
params.getvdw = True
params.getvdwstrain = True
params.getburiedvolume = True
params.getbondlength = True
params.getatomdistance = True
params.getbondangle = None
params.getdihedral = None
params.getbondmidpoint = True
params.getmomentdescriptors = ['geometric','sterimol']
params.getsolidanglecoverage = True 
params.getMoRSEweights= 'mass'  # Weights for MoRSE descriptors
params.getMoRSEbins = 10  # Number of bins for MoRSE descriptors
params.getclusteringcoeff = True
params.getclosenesscentrality = True
params.getdegreecentrality = True
params.getgraphdensity = True
params.getavgdegneighbors = True
params.getnodeclustering = True
params.getassortativity = True
params.getspectralradius = True
params.getdegreeentropy = True
params.getlocalbertzct = True
params.getcoulomb = True
params.getpagerank = True
params.getglobal = True
params.getshortestpath = 'all'
params.bias_walk = 'random'
params.num_walks = 10
params.getuniquewalks = True
params.getrandomwalk = True
params.getshortestpathcount = True
params.getcommonneighbors = 'all'
params.getglobaljaccard = True
params.getglobaladamicadar = True
params.getprefattachment = True
params.getkatz = True
params.getEigenvectorCentrality = True
params.getBetweennessCentralityCorrelation = True
params.getMinCutValue = True
params.getMaximumFlow = True
params.getLaplacianEigenvectorSimilarity = True
params.getFiedlerVectorSimilarity = True
params.getBetweennessCentralityOfPathways = True
params.getRingsInSharedPath = True
params.getfirstpassagetime = True
params.geteffectiveresistance = True
params.getSameAromaticSequence = True
params.getTopoOverlap = True
params.getEdgeClustering = True
params.getFormanCurve = True
params.global_fingerprint_type = 'Morgan'
params.global_similarity_metric = 'Tanimoto'
params.getLocalAtomicEnvironmentSimilarity = True
params.getsamefg = True
params.ct_method = 'spectral'
params.addhbonds = True
params.addcho = True
params.adddihydrogenbonds = True
params.addcationpi = True
params.addpipistack = True
params.addhalogenbonds = True
params.addmetallophilic = True
params.addelectrostatic = True
params.check_hbond = True
params.wt_adj_mat_by = None  # Options: 'bond_order', 'atomic_mass', 'valence', 'hybridization', 'coulomb', 'all'
params.rw_weight_by = None  # Options: 'atomic_mass', 'bond_order', 'hyb', 'valence', 'coulomb', 'all'
params.sp_box_size = None  # For periodic boundary conditions
params.hop_radius = 1  # For k-hop subgraph extraction
params.getrandomwalkcommutetime  = True

# %%
# Define a perfectly atom-mapped reaction SMILES with hydrogens explicitly mapped, including hydrogens in CH3
reaction_smiles = "[H:8][C:1]([H:9])([H:10])[C:2](=[O:3])[O:4][H:5].[O:6][H:7]>>[H:8][C:1]([H:9])([H:10])[C:2]([O:6][H:7])([O:3])[O:4][H:5]"
# Create an instance of BaseReactionFeaturizer
params.k_iter = 2
params.removebondchangeinfo = False
for attribute in ['removebondchangeinfo','addneighboringreactives','gethybridizationchange',
                  'getclosenesscentrality','getdegreecentrality',
                'getbetweennesscentrality',
                'geteigenvectorcentrality',
                'getkatzcentrality',
                'getpagerankcentrality',
                'getkcorenumber',
                'getharmoniccentrality',
                'getlocalbridging',
                'gettrianglecount',
                'getlocalatomfeatures',
                'getvalencychange',
                'getoxidationreduction',
                'getbondordersumchange',
                'getneighborhoodchangeratio']:
    setattr(params, attribute, True)

params.getbondorderchange = True
params.getbondneighborhoodchange = True
params.getshortestpathchangeacrossbond = True
params.getbondparticipationdegree = True
params.getbricsbondrolechange = True
reaction_featurizer = BaseReactionFeaturizer(reaction_smiles, params)
get_dir_to_txt_file(reaction_featurizer,'attributes/BaseReaction.txt')
reaction_helper = ReactionHelper(reaction_smiles, params,BaseFeaturizer)
get_dir_to_txt_file(reaction_featurizer,'attributes/ReactionHelper.txt')
reaction_featurizer = ReactionFeaturizer(reaction_smiles, params)
reaction_featurizer.run()
# Out:
# ╭───────────────────────── <class 'EGAT.src.graph.base.reaction.BaseReactionFeaturizer'> ─────────────────────────╮
# │ ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────╮ │
# │ │ <EGAT.src.graph.base.reaction.BaseReactionFeaturizer object at 0x3330c1180>                                 │ │
# │ ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                                 │
# │        denotation = '>>'                                                                                        │
# │      elementcheck = True                                                                                        │
# │            params = GraphParams(getradical='RDKit', stereo_full=False, acidbase='Lewis')                        │
# │           product = <EGAT.src.graph.base.base.BaseFeaturizer object at 0x107eaff10>                             │
# │          reactant = <EGAT.src.graph.base.base.BaseFeaturizer object at 0x3330c3d30>                             │
# │          reaction = '[H:8][C:1]([H:9])([H:10])[C:2](=[O:3])[O:4][H:5].[O:6][H:7]>>[H:8][C:1]([H:9])([H:10])[C:… │
# │ reactionpropeties = <EGAT.src.utils.descriptors.egat.reactive.Reactive object at 0x3330c1240>                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────── <class 'EGAT.src.graph.base.reaction.BaseReactionFeaturizer'> ─────────────────────────╮
# │ ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────╮ │
# │ │ <EGAT.src.graph.base.reaction.BaseReactionFeaturizer object at 0x3330c1180>                                 │ │
# │ ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                                 │
# │        denotation = '>>'                                                                                        │
# │      elementcheck = True                                                                                        │
# │            params = GraphParams(getradical='RDKit', stereo_full=False, acidbase='Lewis')                        │
# │           product = <EGAT.src.graph.base.base.BaseFeaturizer object at 0x107eaff10>                             │
# │          reactant = <EGAT.src.graph.base.base.BaseFeaturizer object at 0x3330c3d30>                             │
# │          reaction = '[H:8][C:1]([H:9])([H:10])[C:2](=[O:3])[O:4][H:5].[O:6][H:7]>>[H:8][C:1]([H:9])([H:10])[C:… │
# │ reactionpropeties = <EGAT.src.utils.descriptors.egat.reactive.Reactive object at 0x3330c1240>                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2906.74it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 1613.06it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 3888.24it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 6169.13it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 6603.87it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 5943.35it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 6936.17it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 4189.34it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 3753.53it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 5225.43it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 42650.86it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 48867.70it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 16358.17it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 25938.46it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 42113.29it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 10696.27it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 25241.01it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 17815.84it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 48245.79it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 62561.82it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 28413.42it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 30244.29it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 54835.13it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 20964.83it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 26344.02it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 32959.75it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 4180.33it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 5855.40it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 8193.83it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 7885.51it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 8391.25it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 7364.52it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 5983.44it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 5249.82it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 6232.78it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 4841.95it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 38012.40it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 24229.63it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 21353.15it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 30696.40it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 50754.97it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 28854.26it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 23473.72it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 17769.27it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 57123.24it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 24740.50it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 14757.62it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 11043.21it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 7215.41it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 10871.47it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 21085.92it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 19922.41it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 23337.55it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 23651.14it/s]
# Processing Atom Features: 100%|██████████| 18/18 [00:00<00:00, 39548.18it/s]
# Processing Atom Features: 100%|██████████| 18/18 [00:00<00:00, 361231.92it/s]
# Processing Atom Features: 100%|██████████| 18/18 [00:00<00:00, 155344.59it/s]
# Processing Atom Features: 100%|██████████| 18/18 [00:00<00:00, 243540.23it/s]
# Processing Atom Features: 100%|██████████| 18/18 [00:00<00:00, 183246.29it/s]
# Processing Atom Features: 100%|██████████| 18/18 [00:00<00:00, 98818.68it/s]
# Processing Atom Features: 100%|██████████| 18/18 [00:00<00:00, 310689.19it/s]
# Processing Atom Features: 100%|██████████| 18/18 [00:00<00:00, 214481.45it/s]
# Processing Atom Features: 100%|██████████| 18/18 [00:00<00:00, 12336.19it/s]
# Processing Atom Features: 100%|██████████| 18/18 [00:00<00:00, 285975.27it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 98523.92it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 13207.43it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 12047.65it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 13567.53it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 134064.51it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 95948.13it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 19945.74it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 122845.72it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 110792.94it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 179025.17it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 9872.27it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 95948.13it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 146070.29it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 127100.12it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 149796.57it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 132252.83it/s]
# Processing Bond Features:  14%|█▍        | 1/7 [00:00<00:00, 21845.33it/s]
# Traceback (most recent call last):
#   File "/Users/svaddadi/Documents/GitHub/EGAT/src/graph/reaction/Reaction.py", line 92, in GenerateBondFeatureVector
#     self.BondFeatureVector(ind)
#   File "/Users/svaddadi/Documents/GitHub/EGAT/src/graph/reaction/Reaction.py", line 44, in BondFeatureVector
#     self.obtainbondfcn(ind, reactant_bond_features, product_bond_features, reactant_case, product_case, Rmat=self.reactant.matrixdescriptors.adj_mat, Pmat=self.product.matrixdescriptors.adj_mat, removeparams=params[i], func=func)
#   File "/Users/svaddadi/Documents/GitHub/EGAT/src/graph/base/reaction.py", line 140, in obtainbondfcn
#     edge = self.edgefcn(ind,globalfeats=globalfeats)
#   File "/Users/svaddadi/Documents/GitHub/EGAT/src/graph/base/reaction.py", line 133, in edgefcn
#     if not globalfeats and not product: edge = sorted([self.reactant.edges_u[ind],self.reactant.edges_v[ind]])
# IndexError: list index out of range
# Error processing bond feature vector for index 16: list index out of range
# Processing Bond Features:  14%|█▍        | 1/7 [00:00<00:00, 30174.85it/s]
# Error processing bond feature vector for index 17: list index out of range
# Traceback (most recent call last):
#   File "/Users/svaddadi/Documents/GitHub/EGAT/src/graph/reaction/Reaction.py", line 92, in GenerateBondFeatureVector
#     self.BondFeatureVector(ind)
#   File "/Users/svaddadi/Documents/GitHub/EGAT/src/graph/reaction/Reaction.py", line 44, in BondFeatureVector
#     self.obtainbondfcn(ind, reactant_bond_features, product_bond_features, reactant_case, product_case, Rmat=self.reactant.matrixdescriptors.adj_mat, Pmat=self.product.matrixdescriptors.adj_mat, removeparams=params[i], func=func)
#   File "/Users/svaddadi/Documents/GitHub/EGAT/src/graph/base/reaction.py", line 140, in obtainbondfcn
#     edge = self.edgefcn(ind,globalfeats=globalfeats)
#   File "/Users/svaddadi/Documents/GitHub/EGAT/src/graph/base/reaction.py", line 133, in edgefcn
#     if not globalfeats and not product: edge = sorted([self.reactant.edges_u[ind],self.reactant.edges_v[ind]])
# IndexError: list index out of range

# %%
reaction_featurizer = ReactionFeaturizerwithGeometry(reaction_smiles, params)
reaction_featurizer.run()
# Out:
# ic| self.GrabConformer: <bound method BaseFeaturizer.GrabConformer of <EGAT.src.graph.molecular.MoleculeGeometry.MoleculeFeaturizerwithGeometry object at 0x3330c2cb0>>
# ic| self.GrabGeometry: <bound method BaseFeaturizer.GrabGeometry of <EGAT.src.graph.molecular.MoleculeGeometry.MoleculeFeaturizerwithGeometry object at 0x3330c2cb0>>
# ic| self.GrabConformer: <bound method BaseFeaturizer.GrabConformer of <EGAT.src.graph.molecular.MoleculeGeometry.MoleculeFeaturizerwithGeometry object at 0x333084160>>
# ic| self.GrabGeometry: <bound method BaseFeaturizer.GrabGeometry of <EGAT.src.graph.molecular.MoleculeGeometry.MoleculeFeaturizerwithGeometry object at 0x333084160>>
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 7089.42it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 921.56it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2100.29it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1011.44it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 3076.13it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1439.27it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2986.33it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1068.37it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 12199.33it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1567.38it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 7094.22it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 2166.55it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 9004.24it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1750.50it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 6835.25it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1960.53it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 5730.15it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1625.86it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 6006.08it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1765.84it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 24909.31it/s]
# Processing bond 0 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 27025.15it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 30124.13it/s]
# Processing bond 1 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 17476.27it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 11668.08it/s]
# Processing bond 2 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 28074.32it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 31270.98it/s]
# Processing bond 3 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 5974.79it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 11776.83it/s]
# Processing bond 4 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 27776.85it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 21355.46it/s]
# Processing bond 5 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 1736.20it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 12785.85it/s]
# Processing bond 6 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 12618.24it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 15519.78it/s]
# Processing bond 7 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 62601.55it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 15244.94it/s]
# Processing bond 8 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 61141.46it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 16162.36it/s]
# Processing bond 9 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 47662.55it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 59359.32it/s]
# Processing bond 10 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 55043.36it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 20761.69it/s]
# Processing bond 11 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 12221.17it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 15947.92it/s]
# Processing bond 12 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 18657.94it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 17246.92it/s]
# Processing bond 13 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 70374.23it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 40445.69it/s]
# Processing bond 14 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 22844.79it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 27258.34it/s]
# Processing bond 15 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 34492.63it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 4899.89it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1855.32it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 4548.36it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1507.45it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 5926.67it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1820.49it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 8883.28it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1755.72it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 3550.24it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1173.54it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 6084.37it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1651.22it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 5681.80it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1705.00it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 8765.26it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 2002.47it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 7166.08it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1762.54it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 7229.78it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 967.00it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 12506.81it/s]
# Processing bond 0 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 29873.96it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 47273.93it/s]
# Processing bond 1 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 28532.68it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 26496.28it/s]
# Processing bond 2 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 8591.36it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 34088.24it/s]
# Processing bond 3 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 32513.98it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 29088.43it/s]
# Processing bond 4 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 23804.22it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 14697.11it/s]
# Processing bond 5 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 32870.72it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 17368.48it/s]
# Processing bond 6 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 13521.29it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 29322.07it/s]
# Processing bond 7 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 37315.87it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 16101.63it/s]
# Processing bond 8 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 37315.87it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 36019.05it/s]
# Processing bond 9 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 56223.91it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 33164.92it/s]
# Processing bond 10 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 53773.13it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 26196.98it/s]
# Processing bond 11 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 84562.58it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 40478.91it/s]
# Processing bond 12 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 18995.94it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 34995.97it/s]
# Processing bond 13 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 38479.85it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 29688.60it/s]
# Processing bond 14 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 44620.26it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 56696.09it/s]
# Processing bond 15 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 44525.52it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 40763.50it/s]
# Processing bond 16 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 16657.28it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 23121.31it/s]
# Processing bond 17 with edge None in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 77961.04it/s]
# Processing Atom Features: 100%|██████████| 18/18 [00:00<00:00, 304425.29it/s]
# Processing Atom Features: 100%|██████████| 18/18 [00:00<00:00, 300786.74it/s]
# Processing Atom Features: 100%|██████████| 18/18 [00:00<00:00, 352791.93it/s]
# Processing Atom Features: 100%|██████████| 18/18 [00:00<00:00, 124995.81it/s]
# Processing Atom Features: 100%|██████████| 18/18 [00:00<00:00, 242757.14it/s]
# Processing Atom Features: 100%|██████████| 18/18 [00:00<00:00, 300786.74it/s]
# Processing Atom Features: 100%|██████████| 18/18 [00:00<00:00, 242757.14it/s]
# Processing Atom Features: 100%|██████████| 18/18 [00:00<00:00, 340078.70it/s]
# Processing Atom Features: 100%|██████████| 18/18 [00:00<00:00, 144079.15it/s]
# Processing Atom Features: 100%|██████████| 18/18 [00:00<00:00, 136031.48it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 114688.00it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 85598.04it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 78503.02it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 141836.37it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 13183.71it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 56461.78it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 127100.12it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 59675.06it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 149036.18it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 60287.74it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 52996.62it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 115137.76it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 88434.12it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 32087.57it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 134679.49it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 134679.49it/s]
# Processing Bond Features:  14%|█▍        | 1/7 [00:00<00:00, 22192.08it/s]
# Processing Bond Features:  14%|█▍        | 1/7 [00:00<00:00, 9915.61it/s]

# %%
reaction_featurizer = ReactionFeaturizerwithPadding(reaction_smiles, params)
reaction_featurizer.run()
# Out:
# ic| self.GrabConformer: <bound method BaseFeaturizer.GrabConformer of <EGAT.src.graph.molecular.MoleculeGlobal.MoleculeFeaturizerwithPadding object at 0x333094c40>>
# ic| self.GrabGeometry: <bound method BaseFeaturizer.GrabGeometry of <EGAT.src.graph.molecular.MoleculeGlobal.MoleculeFeaturizerwithPadding object at 0x333094c40>>
# ic| self.GrabConformer: <bound method BaseFeaturizer.GrabConformer of <EGAT.src.graph.molecular.MoleculeGlobal.MoleculeFeaturizerwithPadding object at 0x333094c40>>
# ic| self.GrabGeometry: <bound method BaseFeaturizer.GrabGeometry of <EGAT.src.graph.molecular.MoleculeGlobal.MoleculeFeaturizerwithPadding object at 0x333094c40>>
# ic| self.GrabConformer: <bound method BaseFeaturizer.GrabConformer of <EGAT.src.graph.molecular.MoleculeGlobal.MoleculeFeaturizerwithPadding object at 0x333094a30>>
# ic| self.GrabGeometry: <bound method BaseFeaturizer.GrabGeometry of <EGAT.src.graph.molecular.MoleculeGlobal.MoleculeFeaturizerwithPadding object at 0x333094a30>>
# ic| self.GrabConformer: <bound method BaseFeaturizer.GrabConformer of <EGAT.src.graph.molecular.MoleculeGlobal.MoleculeFeaturizerwithPadding object at 0x333094a30>>
# ic| self.GrabGeometry: <bound method BaseFeaturizer.GrabGeometry of <EGAT.src.graph.molecular.MoleculeGlobal.MoleculeFeaturizerwithPadding object at 0x333094a30>>
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 6050.52it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1224.90it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): nan
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 250.86it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2842.99it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1497.73it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): nan
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 1049.91it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 3766.87it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1461.33it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): 0
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 588.11it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 2371.44it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 2082.77it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): nan
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 979.06it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 6150.65it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1766.81it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): 0
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 1102.22it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 6323.93it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1567.89it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): 0
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 908.18it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 9807.96it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1948.40it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): 0
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 1036.83it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 9051.99it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1955.56it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): 0
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 906.61it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 6649.63it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1604.82it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): 0
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 968.76it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 7059.93it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1779.98it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): 0
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 1011.35it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 35214.77it/s]
# ic| edge: [0, 1]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 5365.41it/s]
# ic| edge: [0, 1]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7115.95it/s]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 41519.02it/s]
# ic| edge: [0, 5]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7313.52it/s]
# ic| edge: [0, 5]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7276.92it/s]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 44289.44it/s]
# ic| edge: [0, 6]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7268.19it/s]
# ic| edge: [0, 6]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6929.65it/s]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 42761.88it/s]
# ic| edge: [0, 7]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7840.95it/s]
# ic| edge: [0, 7]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7203.85it/s]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 37721.45it/s]
# ic| edge: [0, 1]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7266.74it/s]
# ic| edge: [0, 1]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6879.81it/s]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 54972.75it/s]
# ic| edge: [1, 2]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 13619.57it/s]
# ic| edge: [1, 2]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 11324.19it/s]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 33988.33it/s]
# ic| edge: [1, 3]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 10997.57it/s]
# ic| edge: [1, 3]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 11125.47it/s]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 30816.37it/s]
# ic| edge: [1, 2]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 11535.00it/s]
# ic| edge: [1, 2]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 699.56it/s]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 1635.18it/s]
# ic| edge: [1, 3]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3463.50it/s]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# ic| edge: [1, 3]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 13104.05it/s]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 32322.07it/s]
# ic| edge: [3, 8]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4665.12it/s]
# ic| edge: [3, 8]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4430.30it/s]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 31270.98it/s]
# ic| edge: [4, 9]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 10744.03it/s]
# ic| edge: [4, 9]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7829.13it/s]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 33457.62it/s]
# ic| edge: [0, 5]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7766.12it/s]
# ic|
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
#  edge: [0, 5]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6847.41it/s]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 26553.38it/s]
# ic| edge: [0, 6]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6668.21it/s]
# ic| edge: [0, 6]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7090.50it/s]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 39728.39it/s]
# ic| edge: [0, 7]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6997.23it/s]
# ic| edge: [0, 7]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7725.96it/s]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 30244.29it/s]
# ic| edge: [3, 8]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7378.34it/s]
# ic| edge: [3, 8]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6737.42it/s]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 35315.71it/s]
# ic| edge: [4, 9]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 8663.85it/s]
# ic| edge: [4, 9]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 10132.11it/s]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing global bonds (outer loop):   0%|          | 0/10 [00:00<?, ?it/s]ic| edge: [0, 2]
# ic| edge: [0, 2]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 34105.93it/s]
# Processing bond [0, 2] with edge [0, 2] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 60963.72it/s]
# ic| edge: [0, 2]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4189.47it/s]
# ic| edge: [0, 3]
# ic| edge: [0, 3]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 42845.53it/s]
# Processing bond [0, 3] with edge [0, 3] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 68534.38it/s]
# ic| edge: [0, 3]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4637.94it/s]
# ic| edge: [
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# 0, 4]
# ic| edge: [0, 4]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 37757.57it/s]
# Processing bond [0, 4] with edge [0, 4] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 42111.49it/s]
# ic| edge: [0, 4]
# Method spectral failed: Graph must be connected to compute commute time.
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 200.81it/s]
# ic| edge: [0, 8]
# ic
# Error computing resistance distance: Graph G must be strongly connected.
# | edge: [0, 8]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 39592.75it/s]
# Processing bond [0, 8] with edge [0, 8] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 59578.18it/s]
# ic| edge: [0, 8]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3740.03it/s]
# ic| edge: [0, 9]
# ic| edge: [0, 9]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 48722.76it/s]
# Processing bond [0, 9] with edge [0, 9] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 47127.01it/s]
# ic| edge: [0, 9]
# Method spectral failed: Graph must be connected to compute commute time.
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 203.09it/s]
# Processing global bonds (outer loop):  10%|█         | 1/10 [00:00<00:03,  2.31it/s]
# Error computing resistance distance: Graph G must be strongly connected.
# ic| edge: [1, 4]
# ic| edge: [1, 4]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 32195.38it/s]
# Processing bond [1, 4] with edge [1, 4] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 49932.19it/s]
# ic| edge: [1, 4]
# Method spectral failed: Graph must be connected to compute commute time.
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 202.10it/s]
# ic| edge: [1, 5]
# ic| edge: [1, 5]
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 33964.90it/s]
# Processing bond [1, 5] with edge [1, 5] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 86302.55it/s]
# ic| edge: [1, 5]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 5215.55it/s]
# ic| edge: [1, 6]
# ic| edge: [1, 6]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 43594.05it/s]
# Processing bond [1, 6] with edge [1, 6] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 65741.44it/s]
# ic| edge: [1, 6]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 489.92it/s]
# ic| edge: [1, 7]
# ic| edge: [1, 7]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 38782.67it/s]
# Processing bond [1, 7] with edge [1, 7] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 15330.06it/s]
# ic| edge: [1, 7]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 5226.30it/s]
# ic| edge: [1, 8]
# ic| edge: [1, 8]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 34688.07it/s]
# Processing bond [1, 8] with edge [1, 8] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 80659.69it/s]
# ic| edge: [1, 8]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4288.49it/s]
# ic| edge: [1, 9]
# ic| edge: [1, 9]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 29918.39it/s]
# Processing bond [1, 9] with edge [1, 9] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 61500.06it/s]
# ic| edge: [1, 9]
#
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 198.46it/s]
# Processing global bonds (outer loop):  20%|██        | 2/10 [00:01<00:04,  1.82it/s]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# ic| edge: [2, 3]
# ic| edge: [2, 3]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 53583.12it/s]
# Processing bond [2, 3] with edge [2, 3] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 34952.53it/s]
# ic| edge: [2, 3]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7420.52it/s]
# ic| edge: [2, 4]
# ic| edge: [2, 4]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 30821.18it/s]
# Processing bond [2, 4] with edge [2, 4] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 60090.32it/s]
# ic| edge: [2, 4]
# Method spectral failed: Graph must be connected to compute commute time.
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 197.91it/s]
# ic| edge: [2, 5]
# ic| edge: [2, 5]
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 29670.72it/s]
# Processing bond [2, 5] with edge [2, 5] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 71331.70it/s]
# ic| edge: [2, 5]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4462.21it/s]
# ic| edge: [2, 6]
# ic| edge: [2, 6]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 30147.16it/s]
# Processing bond [2, 6] with edge [2, 6] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 86302.55it/s]
# ic| edge: [2, 6]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3842.02it/s]
# ic| edge: [2, 7]
# ic| edge: [2, 7]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 20898.15it/s]
# Processing bond [2, 7] with edge [2, 7] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 69212.94it/s]
# ic| edge: [2, 7]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3813.40it/s]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# ic| edge: [2, 8]
# ic| edge: [2, 8]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 20779.20it/s]
# Processing bond [2, 8] with edge [2, 8] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 76818.75it/s]
# ic| edge: [2, 8]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3517.80it/s]
# ic| edge: [2, 9]
# ic| edge: [2, 9]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 18303.83it/s]
# Processing bond [2, 9] with edge [2, 9] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 76818.75it/s]
# ic| edge: [2, 9]
# Method spectral failed: Graph must be connected to compute commute time.
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 165.58it/s]
# Processing global bonds (outer loop):  30%|███       | 3/10 [00:01<00:03,  1.84it/s]
# Error computing resistance distance: Graph G must be strongly connected.
# ic| edge: [3, 4]
# ic| edge: [3, 4]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 29559.50it/s]
# Processing bond [3, 4] with edge [3, 4] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 67432.54it/s]
# ic| edge: [3, 4]
# Method spectral failed: Graph must be connected to compute commute time.
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 195.34it/s]
# ic| edge: [3, 5]
# ic| edge: [3, 5]
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 613.50it/s]
# Processing bond [3, 5] with edge [3, 5] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 14483.09it/s]
# ic| edge: [3, 5]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 794.09it/s]
# ic| edge: [3, 6]
# ic| edge: [3, 6]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 7244.05it/s]
# Processing bond [3, 6] with edge [3, 6] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 55627.37it/s]
# ic| edge: [3, 6]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 1771.96it/s]
# ic| edge: [3, 7]
# ic| edge: [3, 7]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 29157.27it/s]
# Processing bond [3, 7] with edge [3, 7] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 26181.67it/s]
# ic| edge: [3, 7]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3636.88it/s]
# ic| edge: [3, 9]
# ic| edge: [3, 9]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 29374.50it/s]
# Processing bond [3, 9] with edge [3, 9] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 53227.21it/s]
# ic| edge: [3, 9]
# Method spectral failed: Graph must be connected to compute commute time.
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 190.83it/s]
# Processing global bonds (outer loop):  40%|████      | 4/10 [00:02<00:03,  1.64it/s]
# Error computing resistance distance: Graph G must be strongly connected.
# ic| edge: [4, 5]
# ic| edge: [4, 5]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 34301.77it/s]
# Processing bond [4, 5] with edge [4, 5] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 73584.28it/s]
# ic| edge: [4, 5]
# Method spectral failed: Graph must be connected to compute commute time.
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 209.12it/s]
# ic| edge: [4, 6]
# ic| edge: [4, 6]
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 26432.33it/s]
# Processing bond [4, 6] with edge [4, 6] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 47662.55it/s]
# ic| edge: [4, 6]
#
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 207.48it/s]
# ic| edge: [4, 7]
# ic| edge: [4, 7]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 31435.54it/s]
# Processing bond [4, 7] with edge [4, 7] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 73326.99it/s]
# ic| edge: [4, 7]
# Method spectral failed: Graph must be connected to compute commute time.
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 206.18it/s]
# ic| edge: [4, 8]
# ic| edge: [4, 8]
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 28540.94it/s]
# Processing bond [4, 8] with edge [4, 8] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 76818.75it/s]
# ic| edge: [4, 8]
# Method spectral failed: Graph must be connected to compute commute time.
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 202.62it/s]
# Processing global bonds (outer loop):  50%|█████     | 5/10 [00:02<00:03,  1.67it/s]
# Error computing resistance distance: Graph G must be strongly connected.
# ic| edge: [5, 6]
# ic| edge: [5, 6]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 35525.73it/s]
# Processing bond [5, 6] with edge [5, 6] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 71575.15it/s]
# ic| edge: [5, 6]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 5729.32it/s]
# ic| edge: [5, 7]
# ic| edge: [5, 7]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 37061.91it/s]
# Processing bond [5, 7] with edge [5, 7] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 83551.87it/s]
# ic| edge: [5, 7]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6765.85it/s]
# ic
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# | edge: [5, 8]
# ic| edge: [5, 8]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 41362.21it/s]
# Processing bond [5, 8] with edge [5, 8] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 59409.41it/s]
# ic| edge: [5, 8]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3208.35it/s]
# ic| edge: [5, 9]
# ic| edge: [5, 9]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 31122.87it/s]
# Processing bond [5, 9] with edge [5, 9] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 53773.13it/s]
# ic| edge: [5, 9]
# Method spectral failed: Graph must be connected to compute commute time.
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 201.39it/s]
# Processing global bonds (outer loop):  60%|██████    | 6/10 [00:03<00:01,  2.08it/s]
# Error computing resistance distance: Graph G must be strongly connected.
# ic| edge: [6, 7]
# ic| edge: [6, 7]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 35151.98it/s]
# Processing bond [6, 7] with edge [6, 7] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 79437.58it/s]
# ic| edge: [6, 7]
# Method spectral failed: Graph must be connected to compute commute time.
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 284.51it/s]
# Error computing resistance distance: Graph G must be strongly connected.
# ic| edge: [6, 8]
# ic| edge: [6, 8]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 6155.96it/s]
# Processing bond [6, 8] with edge [6, 8] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 29789.09it/s]
# ic| edge: [6, 8]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3441.53it/s]
# ic| edge: [6, 9]
# ic| edge: [6, 9]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 35366.40it/s]
# Processing bond [6, 9] with edge [6, 9] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 51025.60it/s]
# ic| edge: [6, 9]
#
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 191.46it/s]
# Processing global bonds (outer loop):  70%|███████   | 7/10 [00:03<00:01,  2.20it/s]
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# ic| edge: [7, 8]
# ic| edge: [7, 8]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 27613.43it/s]
# Processing bond [7, 8] with edge [7, 8] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 64726.91it/s]
# ic| edge: [7, 8]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3031.75it/s]
# ic
# Method spectral failed: Graph must be connected to compute commute time.
# Error computing resistance distance: Graph G must be strongly connected.
# | edge: [7, 9]
# ic| edge: [7, 9]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 36662.13it/s]
# Processing bond [7, 9] with edge [7, 9] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 62601.55it/s]
# ic| edge: [7, 9]
# Method spectral failed: Graph must be connected to compute commute time.
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 152.31it/s]
# Processing global bonds (outer loop):  80%|████████  | 8/10 [00:03<00:00,  2.63it/s]
# Error computing resistance distance: Graph G must be strongly connected.
# ic| edge: [8, 9]
# ic| edge: [8, 9]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 30055.24it/s]
# Processing bond [8, 9] with edge [8, 9] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 83220.32it/s]
# ic| edge: [8, 9]
# Method spectral failed: Graph must be connected to compute commute time.
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 198.73it/s]
# Processing global bonds (outer loop):  90%|█████████ | 9/10 [00:03<00:00,  3.21it/s]
# Error computing resistance distance: Graph G must be strongly connected.
# Processing global bonds (outer loop): 100%|██████████| 10/10 [00:03<00:00,  2.55it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 5523.08it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1370.80it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): nan
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 351.07it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 5254.42it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1721.14it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): nan
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 602.44it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 4981.87it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1492.80it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): nan
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 549.41it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 9199.48it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1322.39it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): 0
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 529.85it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 4185.57it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1805.80it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): nan
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 504.21it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 7391.03it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1937.99it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): 0
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 584.79it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 8726.19it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1710.83it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): 0
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 846.64it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 7064.18it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1908.13it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): 0
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 891.98it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 7592.09it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1609.63it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): 0
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 652.15it/s]
# Processing atom features: 100%|██████████| 70/70 [00:00<00:00, 6844.65it/s]
# Processing atom functions: 100%|██████████| 16/16 [00:00<00:00, 1482.87it/s]
# Processing atom functions:   0%|          | 0/13 [00:00<?, ?it/s]ic| self.Assortativity(ind): 0
# Processing atom functions: 100%|██████████| 13/13 [00:00<00:00, 624.85it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 57322.56it/s]
# ic| edge: [0, 1]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4933.58it/s]
# ic| edge: [0, 1]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6259.44it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 48795.12it/s]
# ic| edge: [0, 5]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4660.34it/s]
# ic| edge: [0, 5]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6357.23it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 32976.29it/s]
# ic| edge: [0, 6]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4698.29it/s]
# ic| edge: [0, 6]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 5415.50it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 42920.16it/s]
# ic| edge: [0, 7]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6407.28it/s]
# ic| edge: [0, 7]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4972.50it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 24921.91it/s]
# ic| edge: [0, 1]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3676.98it/s]
# ic| edge: [0, 1]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 5579.24it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 21439.07it/s]
# ic| edge: [1, 2]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 9928.25it/s]
# ic| edge: [1, 2]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 12206.39it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 35660.69it/s]
# ic| edge: [1, 3]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6673.51it/s]
# ic| edge: [1, 3]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 376.18it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 2117.02it/s]
# ic| edge: [1, 4]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3430.60it/s]
# ic| edge: [1, 4]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7127.58it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 9029.51it/s]
# ic| edge: [1, 2]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 9785.71it/s]
# ic| edge: [1, 2]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6539.45it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 23005.29it/s]
# ic| edge: [2, 8]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6624.46it/s]
# ic| edge: [2, 8]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6301.39it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 38218.75it/s]
# ic| edge: [1, 3]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 8521.68it/s]
# ic| edge: [1, 3]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6699.34it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 40553.85it/s]
# ic| edge: [1, 4]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 8436.63it/s]
# ic| edge: [1, 4]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7497.04it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 57963.04it/s]
# ic| edge: [4, 9]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6508.23it/s]
# ic| edge: [4, 9]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7059.29it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 42194.41it/s]
# ic| edge: [0, 5]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7975.71it/s]
# ic| edge: [0, 5]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7606.33it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 46858.16it/s]
# ic| edge: [0, 6]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7573.57it/s]
# ic| edge: [0, 6]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 8617.98it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 41301.55it/s]
# ic| edge: [0, 7]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6876.78it/s]
# ic| edge: [0, 7]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6649.51it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 53164.05it/s]
# ic| edge: [2, 8]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 8259.01it/s]
# ic| edge: [2, 8]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7970.47it/s]
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 40662.60it/s]
# ic| edge: [4, 9]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7826.88it/s]
# ic| edge: [4, 9]
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7909.76it/s]
# Processing global bonds (outer loop):   0%|          | 0/10 [00:00<?, ?it/s]ic| edge: [0, 2]
# ic| edge: [0, 2]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 44843.56it/s]
# Processing bond [0, 2] with edge [0, 2] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 86302.55it/s]
# ic| edge: [0, 2]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6449.72it/s]
# ic| edge: [0, 3]
# ic| edge: [0, 3]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 50482.02it/s]
# Processing bond [0, 3] with edge [0, 3] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 94042.69it/s]
# ic| edge: [0, 3]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6060.80it/s]
# ic| edge: [0, 4]
# ic| edge: [0, 4]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 37420.71it/s]
# Processing bond [0, 4] with edge [0, 4] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 42711.85it/s]
# ic| edge: [0, 4]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 5476.14it/s]
# ic| edge: [0, 8]
# ic| edge: [0, 8]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 48045.89it/s]
# Processing bond [0, 8] with edge [0, 8] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 18657.94it/s]
# ic| edge: [0, 8]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4314.62it/s]
# ic| edge: [0, 9]
# ic| edge: [0, 9]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 41589.09it/s]
# Processing bond [0, 9] with edge [0, 9] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 72315.59it/s]
# ic| edge: [0, 9]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4316.15it/s]
# Processing global bonds (outer loop):  10%|█         | 1/10 [00:00<00:01,  6.60it/s]ic| edge: [1, 5]
# ic| edge: [1, 5]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 36317.67it/s]
# Processing bond [1, 5] with edge [1, 5] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 65741.44it/s]
# ic| edge: [1, 5]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 5301.76it/s]
# ic| edge: [1, 6]
# ic| edge: [1, 6]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 35848.75it/s]
# Processing bond [1, 6] with edge [1, 6] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 76818.75it/s]
# ic| edge: [1, 6]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 338.89it/s]
# ic| edge: [1, 7]
# ic| edge: [1, 7]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 41694.65it/s]
# Processing bond [1, 7] with edge [1, 7] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 68534.38it/s]
# ic| edge: [1, 7]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 2818.46it/s]
# ic| edge: [1, 8]
# ic| edge: [1, 8]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 50702.75it/s]
# Processing bond [1, 8] with edge [1, 8] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 35971.73it/s]
# ic| edge: [1, 8]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4439.14it/s]
# ic| edge: [1, 9]
# ic| edge: [1, 9]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 40214.67it/s]
# Processing bond [1, 9] with edge [1, 9] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 56679.78it/s]
# ic| edge: [1, 9]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4621.24it/s]
# Processing global bonds (outer loop):  20%|██        | 2/10 [00:00<00:02,  3.64it/s]ic| edge: [2, 3]
# ic| edge: [2, 3]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 33037.09it/s]
# Processing bond [2, 3] with edge [2, 3] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 73843.38it/s]
# ic| edge: [2, 3]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7136.90it/s]
# ic| edge: [2, 4]
# ic| edge: [2, 4]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 56163.05it/s]
# Processing bond [2, 4] with edge [2, 4] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 81920.00it/s]
# ic| edge: [2, 4]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7132.70it/s]
# ic| edge: [2, 5]
# ic| edge: [2, 5]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 34129.55it/s]
# Processing bond [2, 5] with edge [2, 5] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 55043.36it/s]
# ic| edge: [2, 5]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 5164.91it/s]
# ic| edge: [2, 6]
# ic| edge: [2, 6]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 44130.80it/s]
# Processing bond [2, 6] with edge [2, 6] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 83551.87it/s]
# ic| edge: [2, 6]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6440.20it/s]
# ic| edge: [2, 7]
# ic| edge: [2, 7]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 40173.69it/s]
# Processing bond [2, 7] with edge [2, 7] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 75709.46it/s]
# ic| edge: [2, 7]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4595.14it/s]
# ic| edge: [2, 9]
# ic| edge: [2, 9]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 42882.81it/s]
# Processing bond [2, 9] with edge [2, 9] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 79437.58it/s]
# ic| edge: [2, 9]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 5271.77it/s]
# Processing global bonds (outer loop):  30%|███       | 3/10 [00:00<00:01,  4.23it/s]ic| edge: [3, 4]
# ic| edge: [3, 4]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 33429.25it/s]
# Processing bond [3, 4] with edge [3, 4] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 83220.32it/s]
# ic| edge: [3, 4]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6722.06it/s]
# ic| edge: [3, 5]
# ic| edge: [3, 5]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 34058.79it/s]
# Processing bond [3, 5] with edge [3, 5] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 61141.46it/s]
# ic| edge: [3, 5]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 5036.81it/s]
# ic| edge: [3, 6]
# ic| edge: [3, 6]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 35258.86it/s]
# Processing bond [3, 6] with edge [3, 6] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 46707.17it/s]
# ic| edge: [3, 6]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 5508.23it/s]
# ic| edge: [3, 7]
# ic| edge: [3, 7]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 30946.98it/s]
# Processing bond [3, 7] with edge [3, 7] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 43965.45it/s]
# ic| edge: [3, 7]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 5059.24it/s]
# ic| edge: [3, 8]
# ic| edge: [3, 8]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 47194.71it/s]
# Processing bond [3, 8] with edge [3, 8] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 64927.31it/s]
# ic| edge: [3, 8]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 5822.00it/s]
# ic| edge: [3, 9]
# ic| edge: [3, 9]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 34633.22it/s]
# Processing bond [3, 9] with edge [3, 9] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 1033.23it/s]
# ic| edge: [3, 9]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 1504.45it/s]
# Processing global bonds (outer loop):  40%|████      | 4/10 [00:01<00:01,  3.60it/s]ic| edge: [4, 5]
# ic| edge: [4, 5]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 21056.64it/s]
# Processing bond [4, 5] with edge [4, 5] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 42711.85it/s]
# ic| edge: [4, 5]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6043.67it/s]
# ic| edge: [4, 6]
# ic| edge: [4, 6]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 33959.05it/s]
# Processing bond [4, 6] with edge [4, 6] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 83220.32it/s]
# ic| edge: [4, 6]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 5180.37it/s]
# ic| edge: [4, 7]
# ic| edge: [4, 7]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 33282.51it/s]
# Processing bond [4, 7] with edge [4, 7] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 43151.28it/s]
# ic| edge: [4, 7]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4422.58it/s]
# ic| edge: [4, 8]
# ic| edge: [4, 8]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 33889.00it/s]
# Processing bond [4, 8] with edge [4, 8] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 60090.32it/s]
# ic| edge: [4, 8]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 5201.87it/s]
# Processing global bonds (outer loop):  50%|█████     | 5/10 [00:01<00:01,  4.01it/s]ic| edge: [5, 6]
# ic| edge: [5, 6]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 35686.51it/s]
# Processing bond [5, 6] with edge [5, 6] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 55043.36it/s]
# ic| edge: [5, 6]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 7325.80it/s]
# ic| edge: [5, 7]
# ic| edge: [5, 7]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 50482.02it/s]
# Processing bond [5, 7] with edge [5, 7] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 26613.60it/s]
# ic| edge: [5, 7]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6832.83it/s]
# ic| edge: [5, 8]
# ic| edge: [5, 8]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 39560.96it/s]
# Processing bond [5, 8] with edge [5, 8] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 69442.12it/s]
# ic| edge: [5, 8]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 3822.36it/s]
# ic| edge: [5, 9]
# ic| edge: [5, 9]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 46724.88it/s]
# Processing bond [5, 9] with edge [5, 9] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 41943.04it/s]
# ic| edge: [5, 9]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4449.10it/s]
# Processing global bonds (outer loop):  60%|██████    | 6/10 [00:01<00:00,  4.69it/s]ic| edge: [6, 7]
# ic| edge: [6, 7]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 37851.82it/s]
# Processing bond [6, 7] with edge [6, 7] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 92385.55it/s]
# ic| edge: [6, 7]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 6096.37it/s]
# ic| edge: [6, 8]
# ic| edge: [6, 8]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 36098.20it/s]
# Processing bond [6, 8] with edge [6, 8] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 66576.25it/s]
# ic| edge: [6, 8]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4870.56it/s]
# ic| edge: [6, 9]
# ic| edge: [6, 9]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 33338.79it/s]
# Processing bond [6, 9] with edge [6, 9] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 43781.88it/s]
# ic| edge: [6, 9]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4453.46it/s]
# ic| edge: [7, 8]
# ic| edge: [7, 8]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 35927.15it/s]
# Processing bond [7, 8] with edge [7, 8] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 48884.66it/s]
# ic| edge: [7, 8]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4752.13it/s]
# ic| edge: [7, 9]
# ic| edge: [7, 9]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 32428.41it/s]
# Processing bond [7, 9] with edge [7, 9] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 53092.46it/s]
# ic| edge: [7, 9]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 4658.55it/s]
# Processing global bonds (outer loop):  80%|████████  | 8/10 [00:01<00:00,  6.67it/s]ic| edge: [8, 9]
# ic| edge: [8, 9]
#
# Processing bond features: 100%|██████████| 47/47 [00:00<00:00, 40059.40it/s]
# Processing bond [8, 9] with edge [8, 9] in this function
# Processing bond functions: 100%|██████████| 5/5 [00:00<00:00, 45491.37it/s]
# ic| edge: [8, 9]
#
# Processing bond functions: 100%|██████████| 26/26 [00:00<00:00, 711.26it/s]
# Processing global bonds (outer loop): 100%|██████████| 10/10 [00:01<00:00,  5.67it/s]
# Processing Atom Features: 100%|██████████| 18/18 [00:00<00:00, 43389.35it/s]
# Processing Atom Features: 100%|██████████| 18/18 [00:00<00:00, 311973.02it/s]
# Processing Atom Features: 100%|██████████| 18/18 [00:00<00:00, 385191.18it/s]
# Processing Atom Features: 100%|██████████| 18/18 [00:00<00:00, 391178.61it/s]
# Processing Atom Features: 100%|██████████| 18/18 [00:00<00:00, 276547.52it/s]
# Processing Atom Features: 100%|██████████| 18/18 [00:00<00:00, 142987.64it/s]
# Processing Atom Features: 100%|██████████| 18/18 [00:00<00:00, 117050.34it/s]
# Processing Atom Features: 100%|██████████| 18/18 [00:00<00:00, 351151.03it/s]
# Processing Atom Features: 100%|██████████| 18/18 [00:00<00:00, 391178.61it/s]
# Processing Atom Features: 100%|██████████| 18/18 [00:00<00:00, 340078.70it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 120823.57it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 109552.72it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 137196.86it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 42924.16it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 55501.19it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 143220.14it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 99864.38it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 86353.32it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 104857.60it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 92038.02it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 142524.89it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 179025.17it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 41943.04it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 173728.57it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 105993.24it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 103017.99it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 148283.47it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 51964.83it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 107546.26it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 151340.87it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 112923.57it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 60913.13it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 74518.09it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 170698.42it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 149036.18it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 100205.22it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 188205.95it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 120823.57it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 158703.39it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 205315.58it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 129912.07it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 118866.91it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 40000.17it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 99864.38it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 174762.67it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 158703.39it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 124936.71it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 158703.39it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 212754.55it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 166818.91it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 219105.43it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 38279.18it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 155344.59it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 137196.86it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 158703.39it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 163111.82it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 166818.91it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 177940.17it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 129339.77it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 88701.29it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 109552.72it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 169711.72it/s]
# Processing Bond Features: 100%|██████████| 7/7 [00:00<00:00, 137840.98it/s]
# Processing Bond Features:  14%|█▍        | 1/7 [00:00<00:00, 28532.68it/s]
