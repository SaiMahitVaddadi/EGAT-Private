# %%
import sys
sys.path.append("/Users/svaddadi/Documents/GitHub/")
import EGAT
from EGAT import src
from EGAT.src.dataset.base.dataset_setups import DatasetSetups,DatasetParams
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 5
#       3 import EGAT
#       4 from EGAT import src
# ----> 5 from EGAT.src.dataset.base.dataset_setups import DatasetSetups,DatasetParams
#
# File ~/Documents/GitHub/EGAT/src/dataset/base/dataset_setups.py:24
#      22 from ...graph.reaction.ReactionGlobalGeometry import ReactionFeaturizerwithPaddingandGeometry
#      23 from ...graph.molecular.MoleculeGlobal import MoleculeFeaturizerwithPadding
# ---> 24 from ...graph.reaction.ReactionGlobal import ReactionFeaturizerwithPadding
#      25 from ...graph.reaction.Reaction import ReactionFeaturizer
#      26 from ...tools.jepa.tools import mask_uv_vectors,mask_node_features,mask_node_features_v2,mask_edge_features,mask_edge_features_v2,mask_node_and_edges,mask_node_and_edges_v2,mask_node_and_edges_v3,mask_node_and_neighbors
#
# File ~/Documents/GitHub/EGAT/src/graph/reaction/ReactionGlobal.py:14
#      10         super(BaseReactionComponentFeaturizer, self).__init__(smiles, arguments)
#      11         super(MoleculeFeaturizerwithPadding, self).__init__(smiles, arguments)
# ---> 14 class ReactionFeaturizerwithPadding(ReactionFeaturizer,ReactionHelper,ReactiveAtomInformation,ReactiveBondInformation,ReactiveAtomChangeInformation,GlobalReactionBondInformation):
#      15     def __init__(self,reaction_smiles,arguments,denotation='>>'):
#      16         super(BaseReactionFeaturizer, self).__init__(reaction_smiles, arguments,denotation,ReactionComponentFeaturizer)
#
# TypeError: Cannot create a consistent method resolution
# order (MRO) for bases GlobalReactionBondInformation, object, BaseReactionFeaturizer, ReactiveAtomChangeInformation
