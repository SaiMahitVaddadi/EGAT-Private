# %%
import sys
sys.path.append("/Users/svaddadi/Documents/GitHub/")
import EGAT
from EGAT import src
from EGAT.src.utils.descriptors.egat.molmatdesc import MolMatDesc
from EGAT.src.utils.descriptors.fingerprint.twodimensional import Fingerprint
from EGAT.src.utils.descriptors.fingerprint.threedimensional import GeometricFingerprint
from rdkit import Chem
# Out:
# /opt/anaconda3/envs/EGAT_CPU/lib/python3.10/site-packages/transformers/utils/generic.py:311: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   torch.utils._pytree._register_pytree_node(
# /opt/anaconda3/envs/EGAT_CPU/lib/python3.10/site-packages/transformers/utils/generic.py:311: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   torch.utils._pytree._register_pytree_node(

# %%
smiles_list = ["CCO", "CCN", "CCC", "CCCl", "CCBr"]

params = {
    'fpname': 'ecfp',
    'variant': 'raw_bits',
    'radius': 3,
    'use_counts': True,
    'use_features': True,
    'size': 2048,
    'fuzziness': 0.5,
    'paths': 5,
    'author': '',
    'model': '',
    'padding': True
}


fpfunc = Fingerprint(params)
print(fpfunc.smiles_to_fps(smiles_list,params))
# Out:
# Processing SMILES:   0%|          | 0/5 [00:00<?, ?it/s][18:40:31] DEPRECATION WARNING: please use MorganGenerator
# [18:40:31] DEPRECATION WARNING: please use MorganGenerator
# [18:40:31] DEPRECATION WARNING: please use MorganGenerator
# [18:40:31] DEPRECATION WARNING: please use MorganGenerator
# [18:40:31] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES: 100%|██████████| 5/5 [00:00<00:00, 1989.71it/s]
# [array([2, 0, 0, ..., 0, 0, 0]), array([2, 0, 0, ..., 0, 0, 0]), array([3, 0, 0, ..., 0, 0, 0]), array([2, 0, 0, ..., 0, 0, 0]), array([2, 0, 0, ..., 0, 0, 0])]

# %%
fpfunc = GeometricFingerprint()
params['fpname'] = 'mxfp'
print(fpfunc.smiles_to_fp(smiles_list,params))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Documents/GitHub/EGAT/src/utils/descriptors/geometry/geometry.py:111, in ConformerGenerator.Initialize(self, method, seed, verbose)
#     110 try:
# --> 111     failed = self._Case1(seed,5000)
#     112 except:
#
# File ~/Documents/GitHub/EGAT/src/utils/descriptors/geometry/geometry.py:74, in ConformerGenerator._Case1(self, seed, attempts)
#      73 def _Case1(self,seed,attempts):
# ---> 74     failed = rdDistGeom.EmbedMolecule(self.egatecule.new_mol)
#      75     if failed == -1:
#
# ValueError: molecule has no atoms
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/Documents/GitHub/EGAT/src/utils/descriptors/geometry/geometry.py:114, in ConformerGenerator.Initialize(self, method, seed, verbose)
#     113 try:
# --> 114     failed = self._Case2(seed,5000)
#     115 except:
#
# File ~/Documents/GitHub/EGAT/src/utils/descriptors/geometry/geometry.py:84, in ConformerGenerator._Case2(self, seed, attempts)
#      83 def _Case2(self,seed,attempts):
# ---> 84     failed = rdDistGeom.EmbedMolecule(self.egatecule.new_mol,maxAttempts=attempts,randomSeed=seed)
#      85     if failed == -1:
#
# ValueError: molecule has no atoms
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/Documents/GitHub/EGAT/src/utils/descriptors/geometry/geometry.py:117, in ConformerGenerator.Initialize(self, method, seed, verbose)
#     116 try:
# --> 117     failed = self._Case3(seed,5000)
#     118 except:
#
# File ~/Documents/GitHub/EGAT/src/utils/descriptors/geometry/geometry.py:92, in ConformerGenerator._Case3(self, seed, attempts)
#      91 def _Case3(self,seed,attempts):
# ---> 92     failed = rdDistGeom.EmbedMolecule(self.egatecule.new_mol,maxAttempts=attempts,randomSeed=seed,useRandomCoords=True)
#      93     if failed == -1:
#
# ValueError: molecule has no atoms
#
# During handling of the above exception, another exception occurred:
#
# ArgumentError                             Traceback (most recent call last)
# File ~/Documents/GitHub/EGAT/src/utils/descriptors/geometry/geometry.py:120, in ConformerGenerator.Initialize(self, method, seed, verbose)
#     119 try:
# --> 120     failed = self.EmbedwithOpenBabel(seed)
#     121 except Exception as e:
#
# File ~/Documents/GitHub/EGAT/src/utils/descriptors/geometry/geometry.py:148, in ConformerGenerator.EmbedwithOpenBabel(self, seed)
#     147 self.egatecule.new_mol = Chem.MolFromMolBlock(result.stdout,sanitize=False)
# --> 148 failed = rdDistGeom.EmbedMolecule(self.egatecule.new_mol,randomSeed=seed)
#     149 return self._Case4(seed,5000)
#
# ArgumentError: Python argument types in
#     rdkit.Chem.rdDistGeom.EmbedMolecule(NoneType)
# did not match C++ signature:
#     EmbedMolecule(RDKit::ROMol {lvalue} mol, RDKit::DGeomHelpers::EmbedParameters {lvalue} params)
#     EmbedMolecule(RDKit::ROMol {lvalue} mol, unsigned int maxAttempts=0, int randomSeed=-1, bool clearConfs=True, bool useRandomCoords=False, double boxSizeMult=2.0, bool randNegEig=True, unsigned int numZeroFail=1, boost::python::dict {lvalue} coordMap={}, double forceTol=0.001, bool ignoreSmoothingFailures=False, bool enforceChirality=True, bool useExpTorsionAnglePrefs=True, bool useBasicKnowledge=True, bool printExpTorsionAngles=False, bool useSmallRingTorsions=False, bool useMacrocycleTorsions=True, unsigned int ETversion=2, bool useMacrocycle14config=True)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 fpfunc = GeometricFingerprint()
#       2 params['fpname'] = 'mxfp'
# ----> 3 print(fpfunc.smiles_to_fp(smiles_list,params))
#
# File ~/Documents/GitHub/EGAT/src/utils/descriptors/fingerprint/threedimensional.py:88, in GeometricFingerprint.smiles_to_fp(self, smiles, vars)
#      86 elif fpname == 'mxfp':
#      87     fp = MXFPCalculator(dimensionality='3D')
# ---> 88 fps = self.ProcessFP(smiles, fp)
#      89 return fps
#
# File ~/Documents/GitHub/EGAT/src/utils/descriptors/fingerprint/threedimensional.py:46, in GeometricFingerprint.ProcessFP(self, smiles, fp)
#      44 for smi in smiles:
#      45     descriptor = MolMatDesc(smi)
# ---> 46     generator = ConformerGenerator(descriptor)
#      47     if generator.mol is not None:
#      48         print(generator.mol)
#
# File ~/Documents/GitHub/EGAT/src/utils/descriptors/geometry/geometry.py:67, in ConformerGenerator.__init__(self, egatecule, nconfs, method, seed, verbose, theory)
#      65 self.egatecule = egatecule
#      66 self.egatecule.new_mol = self.egatecule.new_mol.GetMol()
# ---> 67 self.Initialize(method,seed,verbose)
#      69 if nconfs == 1:
#      70     self._describe()
#
# File ~/Documents/GitHub/EGAT/src/utils/descriptors/geometry/geometry.py:122, in ConformerGenerator.Initialize(self, method, seed, verbose)
#     120                     failed = self.EmbedwithOpenBabel(seed)
#     121                 except Exception as e:
# --> 122                     raise ValueError(f'Cannot embed molecule. This is the error. \n {e}')
#     123 else:
#     124     self.EmbedMoleculewithMethod(seed,method,verbose)
#
# ValueError: Cannot embed molecule. This is the error.
#  Python argument types in
#     rdkit.Chem.rdDistGeom.EmbedMolecule(NoneType)
# did not match C++ signature:
#     EmbedMolecule(RDKit::ROMol {lvalue} mol, RDKit::DGeomHelpers::EmbedParameters {lvalue} params)
#     EmbedMolecule(RDKit::ROMol {lvalue} mol, unsigned int maxAttempts=0, int randomSeed=-1, bool clearConfs=True, bool useRandomCoords=False, double boxSizeMult=2.0, bool randNegEig=True, unsigned int numZeroFail=1, boost::python::dict {lvalue} coordMap={}, double forceTol=0.001, bool ignoreSmoothingFailures=False, bool enforceChirality=True, bool useExpTorsionAnglePrefs=True, bool useBasicKnowledge=True, bool printExpTorsionAngles=False, bool useSmallRingTorsions=False, bool useMacrocycleTorsions=True, unsigned int ETversion=2, bool useMacrocycle14config=True)
