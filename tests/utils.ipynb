# %%
import sys
sys.path.append("/Users/svaddadi/Documents/GitHub/")
import EGAT
from EGAT import src
from EGAT.src.utils.descriptors.egat.encodings import Encodings 
from rdkit import Chem

# %%
sample = 'CC1=CC=C(C=C1)C2=CC=CC=C2C3=CC=CC=C3C4=CC=CC=C4C5=CC=CC=C5'
mol = Chem.MolFromSmiles(sample)
mol

# %%
encodings = Encodings()
print(dir(encodings))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'an_to_el', 'atom_chiral_encode', 'atom_hybrid_encode', 'atom_stereo_encode', 'atomchirality', 'atomstereo', 'bond', 'bond_encode', 'bond_order_encode', 'bond_rotat_encode', 'bond_stereo_encode', 'bond_stereo_encode_new', 'bondorder', 'bondordernew', 'bondrotation', 'bonds', 'bondstereo', 'bondstereonew', 'charge', 'chirality', 'el_alt_valence', 'el_en', 'el_expand_octet', 'el_mass', 'el_max_bonds', 'el_max_valence', 'el_n_deficient', 'el_n_expand_octet', 'el_pol', 'el_radii', 'el_to_an', 'el_valence', 'electron_deficiency', 'element', 'element_encode', 'elements_and_numbers', 'functionalgroup', 'globalbond', 'hybridization', 'hybridization_full', 'hydrogenbond', 'lowercasedict', 'mass', 'metals', 'octet', 'old_bond_encode', 'old_bond_encoding', 'old_el_max_bonds', 'radii', 'stereo_descriptor_encode', 'stereodescriptor', 'titleizedict', 'valence']
